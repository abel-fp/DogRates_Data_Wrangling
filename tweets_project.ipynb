# %%
import pandas as pd
from numpy import nan
# twitter archive file (downloaded manually)
twi_arch = pd.read_csv("twitter-archive-enhanced.csv")

# %% [markdown]
# # Gathering Data

# %%
# download the image_prediction.tsv file programatically
import requests

url = "https://d17h27t6h515a5.cloudfront.net/topher/2017/August/599fd2ad_image-predictions/image-predictions.tsv"
response = requests.get(url)
with open("image_prediction.tsv", "wb") as file:
    file.write(response.content)

# %%
# load api for twitter
import tweepy

consumer_key = ''
consumer_secret = ''
access_token = ''
access_secret = ''

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)
api = tweepy.API(auth, wait_on_rate_limit=True, wait_on_rate_limit_notify=True)

# %%
# creat the tweet_json.txt file using tweepy
import json
import time

count = 0
not_found = []
with open('tweet_json.txt', 'w') as outfile:
    for t_id in twi_arch.tweet_id:
        start = time.time()
        try:
            tweet = api.get_status(t_id, tweet_mode='extended')
        except:
            print("No status found with that ID # {}\n".format(t_id))
            not_found.append(t_id)
            continue
        json.dump(tweet._json, outfile)
        outfile.write('\n')
        end = time.time()
        lapse = end - start
        count += 1
        print("{} done! in {:.2f} seconds".format(t_id, lapse))
        print("{} tweets collected.\n".format(count))

print("The following twitter id's were not found:", not_found, sep="\n")
# Out:
# 892420643555336193 done! in 0.20 seconds
# 1 tweets collected.
#
# 892177421306343426 done! in 0.17 seconds
# 2 tweets collected.
#
# 891815181378084864 done! in 0.18 seconds
# 3 tweets collected.
#
# 891689557279858688 done! in 0.22 seconds
# 4 tweets collected.
#
# 891327558926688256 done! in 0.22 seconds
# 5 tweets collected.
#
# 891087950875897856 done! in 0.19 seconds
# 6 tweets collected.
#
# 890971913173991426 done! in 0.17 seconds
# 7 tweets collected.
#
# 890729181411237888 done! in 0.23 seconds
# 8 tweets collected.
#
# 890609185150312448 done! in 0.19 seconds
# 9 tweets collected.
#
# 890240255349198849 done! in 0.23 seconds
# 10 tweets collected.
#
# 890006608113172480 done! in 0.16 seconds
# 11 tweets collected.
#
# 889880896479866881 done! in 0.18 seconds
# 12 tweets collected.
#
# 889665388333682689 done! in 0.16 seconds
# 13 tweets collected.
#
# 889638837579907072 done! in 0.19 seconds
# 14 tweets collected.
#
# 889531135344209921 done! in 0.17 seconds
# 15 tweets collected.
#
# 889278841981685760 done! in 0.20 seconds
# 16 tweets collected.
#
# 888917238123831296 done! in 0.17 seconds
# 17 tweets collected.
#
# 888804989199671297 done! in 0.19 seconds
# 18 tweets collected.
#
# 888554962724278272 done! in 0.19 seconds
# 19 tweets collected.
#
# No status found with that ID # 888202515573088257
#
# 888078434458587136 done! in 0.17 seconds
# 20 tweets collected.
#
# 887705289381826560 done! in 0.20 seconds
# 21 tweets collected.
#
# 887517139158093824 done! in 0.16 seconds
# 22 tweets collected.
#
# 887473957103951883 done! in 0.19 seconds
# 23 tweets collected.
#
# 887343217045368832 done! in 0.19 seconds
# 24 tweets collected.
#
# 887101392804085760 done! in 0.19 seconds
# 25 tweets collected.
#
# 886983233522544640 done! in 0.17 seconds
# 26 tweets collected.
#
# 886736880519319552 done! in 0.16 seconds
# 27 tweets collected.
#
# 886680336477933568 done! in 0.19 seconds
# 28 tweets collected.
#
# 886366144734445568 done! in 0.17 seconds
# 29 tweets collected.
#
# 886267009285017600 done! in 0.17 seconds
# 30 tweets collected.
#
# 886258384151887873 done! in 0.19 seconds
# 31 tweets collected.
#
# 886054160059072513 done! in 0.20 seconds
# 32 tweets collected.
#
# 885984800019947520 done! in 0.19 seconds
# 33 tweets collected.
#
# 885528943205470208 done! in 0.22 seconds
# 34 tweets collected.
#
# 885518971528720385 done! in 0.17 seconds
# 35 tweets collected.
#
# 885311592912609280 done! in 0.19 seconds
# 36 tweets collected.
#
# 885167619883638784 done! in 0.19 seconds
# 37 tweets collected.
#
# 884925521741709313 done! in 0.17 seconds
# 38 tweets collected.
#
# 884876753390489601 done! in 0.19 seconds
# 39 tweets collected.
#
# 884562892145688576 done! in 0.18 seconds
# 40 tweets collected.
#
# 884441805382717440 done! in 0.19 seconds
# 41 tweets collected.
#
# 884247878851493888 done! in 0.24 seconds
# 42 tweets collected.
#
# 884162670584377345 done! in 0.19 seconds
# 43 tweets collected.
#
# 883838122936631299 done! in 0.17 seconds
# 44 tweets collected.
#
# 883482846933004288 done! in 0.19 seconds
# 45 tweets collected.
#
# 883360690899218434 done! in 0.20 seconds
# 46 tweets collected.
#
# 883117836046086144 done! in 0.17 seconds
# 47 tweets collected.
#
# 882992080364220416 done! in 0.18 seconds
# 48 tweets collected.
#
# 882762694511734784 done! in 0.17 seconds
# 49 tweets collected.
#
# 882627270321602560 done! in 0.23 seconds
# 50 tweets collected.
#
# 882268110199369728 done! in 0.19 seconds
# 51 tweets collected.
#
# 882045870035918850 done! in 0.18 seconds
# 52 tweets collected.
#
# 881906580714921986 done! in 0.17 seconds
# 53 tweets collected.
#
# 881666595344535552 done! in 0.24 seconds
# 54 tweets collected.
#
# 881633300179243008 done! in 0.19 seconds
# 55 tweets collected.
#
# 881536004380872706 done! in 0.18 seconds
# 56 tweets collected.
#
# 881268444196462592 done! in 0.17 seconds
# 57 tweets collected.
#
# 880935762899988482 done! in 0.20 seconds
# 58 tweets collected.
#
# 880872448815771648 done! in 0.17 seconds
# 59 tweets collected.
#
# 880465832366813184 done! in 0.17 seconds
# 60 tweets collected.
#
# 880221127280381952 done! in 0.23 seconds
# 61 tweets collected.
#
# 880095782870896641 done! in 0.21 seconds
# 62 tweets collected.
#
# 879862464715927552 done! in 0.17 seconds
# 63 tweets collected.
#
# 879674319642796034 done! in 0.18 seconds
# 64 tweets collected.
#
# 879492040517615616 done! in 0.23 seconds
# 65 tweets collected.
#
# 879415818425184262 done! in 0.19 seconds
# 66 tweets collected.
#
# 879376492567855104 done! in 0.18 seconds
# 67 tweets collected.
#
# 879130579576475649 done! in 0.17 seconds
# 68 tweets collected.
#
# 879050749262655488 done! in 0.22 seconds
# 69 tweets collected.
#
# 879008229531029506 done! in 0.19 seconds
# 70 tweets collected.
#
# 878776093423087618 done! in 0.18 seconds
# 71 tweets collected.
#
# 878604707211726852 done! in 0.17 seconds
# 72 tweets collected.
#
# 878404777348136964 done! in 0.18 seconds
# 73 tweets collected.
#
# 878316110768087041 done! in 0.19 seconds
# 74 tweets collected.
#
# 878281511006478336 done! in 0.18 seconds
# 75 tweets collected.
#
# 878057613040115712 done! in 0.17 seconds
# 76 tweets collected.
#
# 877736472329191424 done! in 0.18 seconds
# 77 tweets collected.
#
# 877611172832227328 done! in 0.21 seconds
# 78 tweets collected.
#
# 877556246731214848 done! in 0.19 seconds
# 79 tweets collected.
#
# 877316821321428993 done! in 0.21 seconds
# 80 tweets collected.
#
# 877201837425926144 done! in 0.21 seconds
# 81 tweets collected.
#
# 876838120628539392 done! in 0.17 seconds
# 82 tweets collected.
#
# 876537666061221889 done! in 0.20 seconds
# 83 tweets collected.
#
# 876484053909872640 done! in 0.19 seconds
# 84 tweets collected.
#
# 876120275196170240 done! in 0.18 seconds
# 85 tweets collected.
#
# 875747767867523072 done! in 0.20 seconds
# 86 tweets collected.
#
# 875144289856114688 done! in 0.20 seconds
# 87 tweets collected.
#
# 875097192612077568 done! in 0.18 seconds
# 88 tweets collected.
#
# 875021211251597312 done! in 0.19 seconds
# 89 tweets collected.
#
# 874680097055178752 done! in 0.17 seconds
# 90 tweets collected.
#
# 874434818259525634 done! in 0.17 seconds
# 91 tweets collected.
#
# 874296783580663808 done! in 0.16 seconds
# 92 tweets collected.
#
# 874057562936811520 done! in 0.17 seconds
# 93 tweets collected.
#
# 874012996292530176 done! in 0.18 seconds
# 94 tweets collected.
#
# No status found with that ID # 873697596434513921
#
# 873580283840344065 done! in 0.18 seconds
# 95 tweets collected.
#
# 873337748698140672 done! in 0.19 seconds
# 96 tweets collected.
#
# 873213775632977920 done! in 0.21 seconds
# 97 tweets collected.
#
# 872967104147763200 done! in 0.17 seconds
# 98 tweets collected.
#
# 872820683541237760 done! in 0.20 seconds
# 99 tweets collected.
#
# 872668790621863937 done! in 0.19 seconds
# 100 tweets collected.
#
# 872620804844003328 done! in 0.17 seconds
# 101 tweets collected.
#
# 872486979161796608 done! in 0.19 seconds
# 102 tweets collected.
#
# 872261713294495745 done! in 0.18 seconds
# 103 tweets collected.
#
# 872122724285648897 done! in 0.19 seconds
# 104 tweets collected.
#
# 871879754684805121 done! in 0.20 seconds
# 105 tweets collected.
#
# 871762521631449091 done! in 0.17 seconds
# 106 tweets collected.
#
# 871515927908634625 done! in 0.18 seconds
# 107 tweets collected.
#
# 871166179821445120 done! in 0.19 seconds
# 108 tweets collected.
#
# 871102520638267392 done! in 0.19 seconds
# 109 tweets collected.
#
# 871032628920680449 done! in 0.17 seconds
# 110 tweets collected.
#
# 870804317367881728 done! in 0.18 seconds
# 111 tweets collected.
#
# 870726314365509632 done! in 0.17 seconds
# 112 tweets collected.
#
# 870656317836468226 done! in 0.18 seconds
# 113 tweets collected.
#
# 870374049280663552 done! in 0.17 seconds
# 114 tweets collected.
#
# 870308999962521604 done! in 0.23 seconds
# 115 tweets collected.
#
# 870063196459192321 done! in 0.17 seconds
# 116 tweets collected.
#
# No status found with that ID # 869988702071779329
#
# 869772420881756160 done! in 0.19 seconds
# 117 tweets collected.
#
# 869702957897576449 done! in 0.22 seconds
# 118 tweets collected.
#
# 869596645499047938 done! in 0.17 seconds
# 119 tweets collected.
#
# 869227993411051520 done! in 0.19 seconds
# 120 tweets collected.
#
# 868880397819494401 done! in 0.16 seconds
# 121 tweets collected.
#
# 868639477480148993 done! in 0.20 seconds
# 122 tweets collected.
#
# 868622495443632128 done! in 0.22 seconds
# 123 tweets collected.
#
# 868552278524837888 done! in 0.17 seconds
# 124 tweets collected.
#
# 867900495410671616 done! in 0.16 seconds
# 125 tweets collected.
#
# 867774946302451713 done! in 0.20 seconds
# 126 tweets collected.
#
# 867421006826221569 done! in 0.19 seconds
# 127 tweets collected.
#
# 867072653475098625 done! in 0.19 seconds
# 128 tweets collected.
#
# 867051520902168576 done! in 0.19 seconds
# 129 tweets collected.
# No status found with that ID # 866816280283807744
#
# 866720684873056260 done! in 0.19 seconds
# 130 tweets collected.
#
# 866686824827068416 done! in 0.20 seconds
# 131 tweets collected.
#
# 866450705531457537 done! in 0.17 seconds
# 132 tweets collected.
#
# 866334964761202691 done! in 0.19 seconds
# 133 tweets collected.
#
# 866094527597207552 done! in 0.19 seconds
# 134 tweets collected.
#
# 865718153858494464 done! in 0.17 seconds
# 135 tweets collected.
#
# 865359393868664832 done! in 0.16 seconds
# 136 tweets collected.
#
# 865006731092295680 done! in 0.19 seconds
# 137 tweets collected.
#
# 864873206498414592 done! in 0.17 seconds
# 138 tweets collected.
#
# 864279568663928832 done! in 0.19 seconds
# 139 tweets collected.
#
# 864197398364647424 done! in 0.17 seconds
# 140 tweets collected.
#
# 863907417377173506 done! in 0.19 seconds
# 141 tweets collected.
#
# 863553081350529029 done! in 0.17 seconds
# 142 tweets collected.
#
# 863471782782697472 done! in 0.19 seconds
# 143 tweets collected.
#
# 863432100342583297 done! in 0.17 seconds
# 144 tweets collected.
#
# 863427515083354112 done! in 0.19 seconds
# 145 tweets collected.
#
# 863079547188785154 done! in 0.17 seconds
# 146 tweets collected.
#
# 863062471531167744 done! in 0.17 seconds
# 147 tweets collected.
#
# 862831371563274240 done! in 0.17 seconds
# 148 tweets collected.
#
# 862722525377298433 done! in 0.19 seconds
# 149 tweets collected.
#
# 862457590147678208 done! in 0.19 seconds
# 150 tweets collected.
#
# 862096992088072192 done! in 0.19 seconds
# 151 tweets collected.
#
# No status found with that ID # 861769973181624320
#
# 861383897657036800 done! in 0.17 seconds
# 152 tweets collected.
#
# 861288531465048066 done! in 0.22 seconds
# 153 tweets collected.
#
# 861005113778896900 done! in 0.17 seconds
# 154 tweets collected.
#
# 860981674716409858 done! in 0.19 seconds
# 155 tweets collected.
#
# 860924035999428608 done! in 0.19 seconds
# 156 tweets collected.
#
# 860563773140209665 done! in 0.17 seconds
# 157 tweets collected.
#
# 860524505164394496 done! in 0.17 seconds
# 158 tweets collected.
#
# 860276583193509888 done! in 0.25 seconds
# 159 tweets collected.
#
# 860184849394610176 done! in 0.16 seconds
# 160 tweets collected.
#
# 860177593139703809 done! in 0.19 seconds
# 161 tweets collected.
#
# 859924526012018688 done! in 0.17 seconds
# 162 tweets collected.
#
# 859851578198683649 done! in 0.19 seconds
# 163 tweets collected.
#
# 859607811541651456 done! in 0.19 seconds
# 164 tweets collected.
#
# 859196978902773760 done! in 0.17 seconds
# 165 tweets collected.
#
# 859074603037188101 done! in 0.17 seconds
# 166 tweets collected.
#
# 858860390427611136 done! in 0.19 seconds
# 167 tweets collected.
#
# 858843525470990336 done! in 0.20 seconds
# 168 tweets collected.
#
# 858471635011153920 done! in 0.17 seconds
# 169 tweets collected.
#
# 858107933456039936 done! in 0.19 seconds
# 170 tweets collected.
#
# 857989990357356544 done! in 0.16 seconds
# 171 tweets collected.
#
# 857746408056729600 done! in 0.20 seconds
# 172 tweets collected.
#
# 857393404942143489 done! in 0.17 seconds
# 173 tweets collected.
#
# 857263160327368704 done! in 0.19 seconds
# 174 tweets collected.
#
# 857214891891077121 done! in 0.19 seconds
# 175 tweets collected.
#
# 857062103051644929 done! in 0.17 seconds
# 176 tweets collected.
#
# 857029823797047296 done! in 0.17 seconds
# 177 tweets collected.
#
# 856602993587888130 done! in 0.20 seconds
# 178 tweets collected.
#
# 856543823941562368 done! in 0.17 seconds
# 179 tweets collected.
#
# 856526610513747968 done! in 0.17 seconds
# 180 tweets collected.
#
# 856330835276025856 done! in 0.17 seconds
# 181 tweets collected.
#
# 856288084350160898 done! in 0.17 seconds
# 182 tweets collected.
#
# 856282028240666624 done! in 0.20 seconds
# 183 tweets collected.
#
# 855862651834028034 done! in 0.17 seconds
# 184 tweets collected.
#
# 855860136149123072 done! in 0.19 seconds
# 185 tweets collected.
#
# 855857698524602368 done! in 0.19 seconds
# 186 tweets collected.
#
# 855851453814013952 done! in 0.17 seconds
# 187 tweets collected.
#
# 855818117272018944 done! in 0.20 seconds
# 188 tweets collected.
#
# 855459453768019968 done! in 0.22 seconds
# 189 tweets collected.
#
# 855245323840757760 done! in 0.19 seconds
# 190 tweets collected.
#
# 855138241867124737 done! in 0.20 seconds
# 191 tweets collected.
#
# 854732716440526848 done! in 0.16 seconds
# 192 tweets collected.
#
# 854482394044301312 done! in 0.20 seconds
# 193 tweets collected.
#
# 854365224396361728 done! in 0.19 seconds
# 194 tweets collected.
#
# 854120357044912130 done! in 0.19 seconds
# 195 tweets collected.
#
# 854010172552949760 done! in 0.16 seconds
# 196 tweets collected.
#
# 853760880890318849 done! in 0.22 seconds
# 197 tweets collected.
#
# 853639147608842240 done! in 0.22 seconds
# 198 tweets collected.
#
# 853299958564483072 done! in 0.17 seconds
# 199 tweets collected.
#
# 852936405516943360 done! in 0.20 seconds
# 200 tweets collected.
#
# 852912242202992640 done! in 0.17 seconds
# 201 tweets collected.
#
# 852672615818899456 done! in 0.19 seconds
# 202 tweets collected.
#
# 852553447878664193 done! in 0.19 seconds
# 203 tweets collected.
#
# 852311364735569921 done! in 0.19 seconds
# 204 tweets collected.
#
# 852226086759018497 done! in 0.22 seconds
# 205 tweets collected.
#
# 852189679701164033 done! in 0.19 seconds
# 206 tweets collected.
#
# 851953902622658560 done! in 0.20 seconds
# 207 tweets collected.
#
# 851861385021730816 done! in 0.20 seconds
# 208 tweets collected.
#
# 851591660324737024 done! in 0.17 seconds
# 209 tweets collected.
#
# 851464819735769094 done! in 0.20 seconds
# 210 tweets collected.
#
# 851224888060895234 done! in 0.22 seconds
# 211 tweets collected.
#
# 850753642995093505 done! in 0.19 seconds
# 212 tweets collected.
#
# 850380195714523136 done! in 0.19 seconds
# 213 tweets collected.
#
# 850333567704068097 done! in 0.17 seconds
# 214 tweets collected.
#
# 850145622816686080 done! in 0.19 seconds
# 215 tweets collected.
#
# 850019790995546112 done! in 0.25 seconds
# 216 tweets collected.
#
# 849776966551130114 done! in 0.20 seconds
# 217 tweets collected.
#
# 849668094696017920 done! in 0.16 seconds
# 218 tweets collected.
#
# 849412302885593088 done! in 0.17 seconds
# 219 tweets collected.
#
# 849336543269576704 done! in 0.22 seconds
# 220 tweets collected.
#
# 849051919805034497 done! in 0.17 seconds
# 221 tweets collected.
#
# 848690551926992896 done! in 0.17 seconds
# 222 tweets collected.
#
# 848324959059550208 done! in 0.19 seconds
# 223 tweets collected.
#
# 848213670039564288 done! in 0.17 seconds
# 224 tweets collected.
#
# 848212111729840128 done! in 0.19 seconds
# 225 tweets collected.
#
# 847978865427394560 done! in 0.16 seconds
# 226 tweets collected.
#
# 847971574464610304 done! in 0.19 seconds
# 227 tweets collected.
#
# 847962785489326080 done! in 0.17 seconds
# 228 tweets collected.
#
# 847842811428974592 done! in 0.17 seconds
# 229 tweets collected.
#
# 847617282490613760 done! in 0.19 seconds
# 230 tweets collected.
#
# 847606175596138505 done! in 0.19 seconds
# 231 tweets collected.
#
# 847251039262605312 done! in 0.20 seconds
# 232 tweets collected.
#
# 847157206088847362 done! in 0.20 seconds
# 233 tweets collected.
#
# 847116187444137987 done! in 0.19 seconds
# 234 tweets collected.
#
# 846874817362120707 done! in 0.19 seconds
# 235 tweets collected.
#
# 846514051647705089 done! in 0.19 seconds
# 236 tweets collected.
#
# 846505985330044928 done! in 0.20 seconds
# 237 tweets collected.
#
# 846153765933735936 done! in 0.17 seconds
# 238 tweets collected.
#
# 846139713627017216 done! in 0.22 seconds
# 239 tweets collected.
#
# 846042936437604353 done! in 0.20 seconds
# 240 tweets collected.
#
# 845812042753855489 done! in 0.17 seconds
# 241 tweets collected.
#
# 845677943972139009 done! in 0.20 seconds
# 242 tweets collected.
#
# No status found with that ID # 845459076796616705
#
# 845397057150107648 done! in 0.21 seconds
# 243 tweets collected.
#
# 845306882940190720 done! in 0.19 seconds
# 244 tweets collected.
#
# 845098359547420673 done! in 0.19 seconds
# 245 tweets collected.
#
# 844979544864018432 done! in 0.20 seconds
# 246 tweets collected.
#
# 844973813909606400 done! in 0.22 seconds
# 247 tweets collected.
#
# 844704788403113984 done! in 0.16 seconds
# 248 tweets collected.
#
# 844580511645339650 done! in 0.22 seconds
# 249 tweets collected.
#
# 844223788422217728 done! in 0.17 seconds
# 250 tweets collected.
#
# 843981021012017153 done! in 0.19 seconds
# 251 tweets collected.
#
# 843856843873095681 done! in 0.19 seconds
# 252 tweets collected.
#
# 843604394117681152 done! in 0.19 seconds
# 253 tweets collected.
#
# 843235543001513987 done! in 0.19 seconds
# 254 tweets collected.
#
# No status found with that ID # 842892208864923648
#
# 842846295480000512 done! in 0.17 seconds
# 255 tweets collected.
# 842765311967449089 done! in 0.17 seconds
# 256 tweets collected.
#
# 842535590457499648 done! in 0.19 seconds
# 257 tweets collected.
#
# 842163532590374912 done! in 0.19 seconds
# 258 tweets collected.
#
# 842115215311396866 done! in 0.17 seconds
# 259 tweets collected.
#
# 841833993020538882 done! in 0.20 seconds
# 260 tweets collected.
#
# 841680585030541313 done! in 0.19 seconds
# 261 tweets collected.
#
# 841439858740625411 done! in 0.19 seconds
# 262 tweets collected.
#
# 841320156043304961 done! in 0.17 seconds
# 263 tweets collected.
#
# 841314665196081154 done! in 0.19 seconds
# 264 tweets collected.
#
# 841077006473256960 done! in 0.19 seconds
# 265 tweets collected.
#
# 840761248237133825 done! in 0.17 seconds
# 266 tweets collected.
#
# 840728873075638272 done! in 0.19 seconds
# 267 tweets collected.
#
# 840698636975636481 done! in 0.20 seconds
# 268 tweets collected.
#
# 840696689258311684 done! in 0.19 seconds
# 269 tweets collected.
#
# 840632337062862849 done! in 0.16 seconds
# 270 tweets collected.
#
# 840370681858686976 done! in 0.19 seconds
# 271 tweets collected.
#
# 840268004936019968 done! in 0.17 seconds
# 272 tweets collected.
#
# 839990271299457024 done! in 0.19 seconds
# 273 tweets collected.
#
# 839549326359670784 done! in 0.16 seconds
# 274 tweets collected.
#
# 839290600511926273 done! in 0.18 seconds
# 275 tweets collected.
#
# 839239871831150596 done! in 0.19 seconds
# 276 tweets collected.
#
# 838952994649550848 done! in 0.17 seconds
# 277 tweets collected.
#
# 838921590096166913 done! in 0.17 seconds
# 278 tweets collected.
#
# 838916489579200512 done! in 0.20 seconds
# 279 tweets collected.
#
# 838831947270979586 done! in 0.19 seconds
# 280 tweets collected.
#
# 838561493054533637 done! in 0.17 seconds
# 281 tweets collected.
#
# 838476387338051585 done! in 0.19 seconds
# 282 tweets collected.
#
# 838201503651401729 done! in 0.19 seconds
# 283 tweets collected.
#
# 838150277551247360 done! in 0.19 seconds
# 284 tweets collected.
#
# 838085839343206401 done! in 0.17 seconds
# 285 tweets collected.
#
# 838083903487373313 done! in 0.20 seconds
# 286 tweets collected.
#
# 837820167694528512 done! in 0.17 seconds
# 287 tweets collected.
#
# 837482249356513284 done! in 0.17 seconds
# 288 tweets collected.
#
# 837471256429613056 done! in 0.17 seconds
# 289 tweets collected.
#
# 837366284874571778 done! in 0.17 seconds
# 290 tweets collected.
#
# 837110210464448512 done! in 0.19 seconds
# 291 tweets collected.
#
# No status found with that ID # 837012587749474308
#
# 836989968035819520 done! in 0.17 seconds
# 292 tweets collected.
#
# 836753516572119041 done! in 0.17 seconds
# 293 tweets collected.
#
# 836677758902222849 done! in 0.20 seconds
# 294 tweets collected.
#
# 836648853927522308 done! in 0.17 seconds
# 295 tweets collected.
#
# 836397794269200385 done! in 0.19 seconds
# 296 tweets collected.
#
# 836380477523124226 done! in 0.19 seconds
# 297 tweets collected.
#
# 836260088725786625 done! in 0.17 seconds
# 298 tweets collected.
#
# 836001077879255040 done! in 0.19 seconds
# 299 tweets collected.
#
# 835685285446955009 done! in 0.19 seconds
# 300 tweets collected.
#
# 835574547218894849 done! in 0.17 seconds
# 301 tweets collected.
#
# 835536468978302976 done! in 0.20 seconds
# 302 tweets collected.
#
# 835309094223372289 done! in 0.20 seconds
# 303 tweets collected.
#
# 835297930240217089 done! in 0.19 seconds
# 304 tweets collected.
#
# 835264098648616962 done! in 0.19 seconds
# 305 tweets collected.
#
# 835246439529840640 done! in 0.17 seconds
# 306 tweets collected.
#
# 835172783151792128 done! in 0.19 seconds
# 307 tweets collected.
#
# 835152434251116546 done! in 0.19 seconds
# 308 tweets collected.
#
# 834931633769889797 done! in 0.17 seconds
# 309 tweets collected.
#
# 834786237630337024 done! in 0.20 seconds
# 310 tweets collected.
#
# 834574053763584002 done! in 0.19 seconds
# 311 tweets collected.
#
# 834477809192075265 done! in 0.17 seconds
# 312 tweets collected.
#
# 834458053273591808 done! in 0.17 seconds
# 313 tweets collected.
#
# 834209720923721728 done! in 0.20 seconds
# 314 tweets collected.
#
# 834167344700198914 done! in 0.19 seconds
# 315 tweets collected.
#
# 834089966724603904 done! in 0.17 seconds
# 316 tweets collected.
#
# 834086379323871233 done! in 0.19 seconds
# 317 tweets collected.
#
# 833863086058651648 done! in 0.19 seconds
# 318 tweets collected.
#
# 833826103416520705 done! in 0.16 seconds
# 319 tweets collected.
#
# 833732339549220864 done! in 0.19 seconds
# 320 tweets collected.
#
# 833722901757046785 done! in 0.20 seconds
# 321 tweets collected.
#
# 833479644947025920 done! in 0.16 seconds
# 322 tweets collected.
#
# 833124694597443584 done! in 0.17 seconds
# 323 tweets collected.
#
# 832998151111966721 done! in 0.20 seconds
# 324 tweets collected.
#
# 832769181346996225 done! in 0.19 seconds
# 325 tweets collected.
#
# 832757312314028032 done! in 0.17 seconds
# 326 tweets collected.
#
# 832682457690300417 done! in 0.23 seconds
# 327 tweets collected.
#
# 832645525019123713 done! in 0.16 seconds
# 328 tweets collected.
#
# 832636094638288896 done! in 0.19 seconds
# 329 tweets collected.
#
# 832397543355072512 done! in 0.19 seconds
# 330 tweets collected.
#
# 832369877331693569 done! in 0.22 seconds
# 331 tweets collected.
#
# 832273440279240704 done! in 0.19 seconds
# 332 tweets collected.
#
# 832215909146226688 done! in 0.19 seconds
# 333 tweets collected.
#
# 832215726631055365 done! in 0.20 seconds
# 334 tweets collected.
#
# 832088576586297345 done! in 0.19 seconds
# 335 tweets collected.
#
# 832040443403784192 done! in 0.17 seconds
# 336 tweets collected.
#
# 832032802820481025 done! in 0.17 seconds
# 337 tweets collected.
#
# 831939777352105988 done! in 0.20 seconds
# 338 tweets collected.
#
# 831926988323639298 done! in 0.17 seconds
# 339 tweets collected.
#
# 831911600680497154 done! in 0.23 seconds
# 340 tweets collected.
#
# 831670449226514432 done! in 0.19 seconds
# 341 tweets collected.
#
# 831650051525054464 done! in 0.19 seconds
# 342 tweets collected.
#
# 831552930092285952 done! in 0.25 seconds
# 343 tweets collected.
#
# 831322785565769729 done! in 0.17 seconds
# 344 tweets collected.
#
# 831315979191906304 done! in 0.16 seconds
# 345 tweets collected.
#
# 831309418084069378 done! in 0.20 seconds
# 346 tweets collected.
#
# 831262627380748289 done! in 0.20 seconds
# 347 tweets collected.
#
# 830956169170665475 done! in 0.17 seconds
# 348 tweets collected.
#
# 830583320585068544 done! in 0.19 seconds
# 349 tweets collected.
#
# 830173239259324417 done! in 0.19 seconds
# 350 tweets collected.
#
# 830097400375152640 done! in 0.16 seconds
# 351 tweets collected.
#
# 829878982036299777 done! in 0.17 seconds
# 352 tweets collected.
#
# 829861396166877184 done! in 0.20 seconds
# 353 tweets collected.
#
# 829501995190984704 done! in 0.17 seconds
# 354 tweets collected.
#
# 829449946868879360 done! in 0.19 seconds
# 355 tweets collected.
#
# 829374341691346946 done! in 0.17 seconds
# 356 tweets collected.
#
# 829141528400556032 done! in 0.19 seconds
# 357 tweets collected.
#
# 829011960981237760 done! in 0.19 seconds
# 358 tweets collected.
#
# 828801551087042563 done! in 0.19 seconds
# 359 tweets collected.
#
# 828770345708580865 done! in 0.17 seconds
# 360 tweets collected.
#
# 828708714936930305 done! in 0.20 seconds
# 361 tweets collected.
#
# 828650029636317184 done! in 0.19 seconds
# 362 tweets collected.
#
# 828409743546925057 done! in 0.19 seconds
# 363 tweets collected.
#
# 828408677031882754 done! in 0.19 seconds
# 364 tweets collected.
#
# 828381636999917570 done! in 0.17 seconds
# 365 tweets collected.
#
# 828376505180889089 done! in 0.17 seconds
# 366 tweets collected.
#
# 828372645993398273 done! in 0.20 seconds
# 367 tweets collected.
#
# 828361771580813312 done! in 0.19 seconds
# 368 tweets collected.
#
# 828046555563323392 done! in 0.17 seconds
# 369 tweets collected.
#
# 828011680017821696 done! in 0.20 seconds
# 370 tweets collected.
#
# 827933404142436356 done! in 0.20 seconds
# 371 tweets collected.
#
# 827653905312006145 done! in 0.20 seconds
# 372 tweets collected.
#
# 827600520311402496 done! in 0.20 seconds
# 373 tweets collected.
#
# 827324948884643840 done! in 0.20 seconds
# 374 tweets collected.
#
# No status found with that ID # 827228250799742977
#
# 827199976799354881 done! in 0.22 seconds
# 375 tweets collected.
#
# 826958653328592898 done! in 0.20 seconds
# 376 tweets collected.
#
# 826848821049180160 done! in 0.19 seconds
# 377 tweets collected.
#
# 826615380357632002 done! in 0.19 seconds
# 378 tweets collected.
#
# 826598799820865537 done! in 0.19 seconds
# 379 tweets collected.
#
# 826598365270007810 done! in 0.20 seconds
# 380 tweets collected.
#
# 826476773533745153 done! in 0.17 seconds
# 381 tweets collected.
#
# 826240494070030336 done! in 0.20 seconds
# 382 tweets collected.
#
# 826204788643753985 done! in 0.19 seconds
# 383 tweets collected.
# 826115272272650244 done! in 0.20 seconds
# 384 tweets collected.
#
# 825876512159186944 done! in 0.20 seconds
# 385 tweets collected.
#
# 825829644528148480 done! in 0.19 seconds
# 386 tweets collected.
#
# 825535076884762624 done! in 0.19 seconds
# 387 tweets collected.
#
# 825147591692263424 done! in 0.16 seconds
# 388 tweets collected.
#
# 825120256414846976 done! in 0.20 seconds
# 389 tweets collected.
#
# 825026590719483904 done! in 0.17 seconds
# 390 tweets collected.
#
# 824796380199809024 done! in 0.19 seconds
# 391 tweets collected.
#
# 824775126675836928 done! in 0.22 seconds
# 392 tweets collected.
#
# 824663926340194305 done! in 0.17 seconds
# 393 tweets collected.
#
# 824325613288833024 done! in 0.17 seconds
# 394 tweets collected.
#
# 824297048279236611 done! in 0.20 seconds
# 395 tweets collected.
#
# 824025158776213504 done! in 0.28 seconds
# 396 tweets collected.
#
# 823939628516474880 done! in 0.17 seconds
# 397 tweets collected.
#
# 823719002937630720 done! in 0.20 seconds
# 398 tweets collected.
#
# 823699002998870016 done! in 0.17 seconds
# 399 tweets collected.
#
# 823581115634085888 done! in 0.19 seconds
# 400 tweets collected.
#
# 823333489516937216 done! in 0.17 seconds
# 401 tweets collected.
#
# 823322678127919110 done! in 0.17 seconds
# 402 tweets collected.
#
# 823269594223824897 done! in 0.17 seconds
# 403 tweets collected.
#
# 822975315408461824 done! in 0.17 seconds
# 404 tweets collected.
#
# 822872901745569793 done! in 0.19 seconds
# 405 tweets collected.
#
# 822859134160621569 done! in 0.19 seconds
# 406 tweets collected.
#
# 822647212903690241 done! in 0.20 seconds
# 407 tweets collected.
#
# 822610361945911296 done! in 0.16 seconds
# 408 tweets collected.
#
# 822489057087389700 done! in 0.19 seconds
# 409 tweets collected.
#
# 822462944365645825 done! in 0.22 seconds
# 410 tweets collected.
#
# 822244816520155136 done! in 0.19 seconds
# 411 tweets collected.
#
# 822163064745328640 done! in 0.19 seconds
# 412 tweets collected.
#
# 821886076407029760 done! in 0.19 seconds
# 413 tweets collected.
#
# 821813639212650496 done! in 0.19 seconds
# 414 tweets collected.
#
# 821765923262631936 done! in 0.20 seconds
# 415 tweets collected.
#
# 821522889702862852 done! in 0.17 seconds
# 416 tweets collected.
#
# 821421320206483457 done! in 0.22 seconds
# 417 tweets collected.
#
# 821407182352777218 done! in 0.19 seconds
# 418 tweets collected.
#
# 821153421864615936 done! in 0.25 seconds
# 419 tweets collected.
#
# 821149554670182400 done! in 0.19 seconds
# 420 tweets collected.
#
# 821107785811234820 done! in 0.17 seconds
# 421 tweets collected.
#
# 821044531881721856 done! in 0.17 seconds
# 422 tweets collected.
#
# 820837357901512704 done! in 0.20 seconds
# 423 tweets collected.
#
# 820749716845686786 done! in 0.17 seconds
# 424 tweets collected.
#
# 820690176645140481 done! in 0.19 seconds
# 425 tweets collected.
#
# 820494788566847489 done! in 0.20 seconds
# 426 tweets collected.
#
# 820446719150292993 done! in 0.19 seconds
# 427 tweets collected.
#
# 820314633777061888 done! in 0.19 seconds
# 428 tweets collected.
#
# 820078625395449857 done! in 0.17 seconds
# 429 tweets collected.
#
# 820013781606658049 done! in 0.20 seconds
# 430 tweets collected.
#
# 819952236453363712 done! in 0.17 seconds
# 431 tweets collected.
#
# 819924195358416896 done! in 0.17 seconds
# 432 tweets collected.
#
# 819711362133872643 done! in 0.20 seconds
# 433 tweets collected.
#
# 819588359383371776 done! in 0.17 seconds
# 434 tweets collected.
#
# 819347104292290561 done! in 0.19 seconds
# 435 tweets collected.
#
# 819238181065359361 done! in 0.17 seconds
# 436 tweets collected.
#
# 819227688460238848 done! in 0.23 seconds
# 437 tweets collected.
#
# 819015337530290176 done! in 0.19 seconds
# 438 tweets collected.
#
# 819015331746349057 done! in 0.19 seconds
# 439 tweets collected.
#
# 819006400881917954 done! in 0.20 seconds
# 440 tweets collected.
#
# 819004803107983360 done! in 0.18 seconds
# 441 tweets collected.
#
# 818646164899774465 done! in 0.17 seconds
# 442 tweets collected.
#
# 818627210458333184 done! in 0.21 seconds
# 443 tweets collected.
#
# 818614493328580609 done! in 0.17 seconds
# 444 tweets collected.
#
# 818588835076603904 done! in 0.17 seconds
# 445 tweets collected.
#
# 818536468981415936 done! in 0.17 seconds
# 446 tweets collected.
#
# 818307523543449600 done! in 0.19 seconds
# 447 tweets collected.
#
# 818259473185828864 done! in 0.19 seconds
# 448 tweets collected.
#
# 818145370475810820 done! in 0.20 seconds
# 449 tweets collected.
#
# 817908911860748288 done! in 0.20 seconds
# 450 tweets collected.
#
# 817827839487737858 done! in 0.20 seconds
# 451 tweets collected.
#
# 817777686764523521 done! in 0.19 seconds
# 452 tweets collected.
#
# 817536400337801217 done! in 0.18 seconds
# 453 tweets collected.
#
# 817502432452313088 done! in 0.22 seconds
# 454 tweets collected.
#
# 817423860136083457 done! in 0.21 seconds
# 455 tweets collected.
#
# 817415592588222464 done! in 0.18 seconds
# 456 tweets collected.
#
# 817181837579653120 done! in 0.17 seconds
# 457 tweets collected.
#
# 817171292965273600 done! in 0.18 seconds
# 458 tweets collected.
#
# 817120970343411712 done! in 0.17 seconds
# 459 tweets collected.
#
# 817056546584727552 done! in 0.18 seconds
# 460 tweets collected.
#
# 816829038950027264 done! in 0.22 seconds
# 461 tweets collected.
#
# 816816676327063552 done! in 0.17 seconds
# 462 tweets collected.
#
# 816697700272001025 done! in 0.20 seconds
# 463 tweets collected.
#
# 816450570814898180 done! in 0.17 seconds
# 464 tweets collected.
#
# 816336735214911488 done! in 0.18 seconds
# 465 tweets collected.
#
# 816091915477250048 done! in 0.19 seconds
# 466 tweets collected.
#
# 816062466425819140 done! in 0.19 seconds
# 467 tweets collected.
#
# 816014286006976512 done! in 0.20 seconds
# 468 tweets collected.
#
# 815990720817401858 done! in 0.19 seconds
# 469 tweets collected.
#
# 815966073409433600 done! in 0.17 seconds
# 470 tweets collected.
#
# 815745968457060357 done! in 0.22 seconds
# 471 tweets collected.
#
# 815736392542261248 done! in 0.17 seconds
# 472 tweets collected.
#
# 815639385530101762 done! in 0.17 seconds
# 473 tweets collected.
#
# 815390420867969024 done! in 0.19 seconds
# 474 tweets collected.
#
# 814986499976527872 done! in 0.19 seconds
# 475 tweets collected.
#
# 814638523311648768 done! in 0.19 seconds
# 476 tweets collected.
#
# 814578408554463233 done! in 0.17 seconds
# 477 tweets collected.
#
# 814530161257443328 done! in 0.19 seconds
# 478 tweets collected.
#
# 814153002265309185 done! in 0.19 seconds
# 479 tweets collected.
#
# 813944609378369540 done! in 0.38 seconds
# 480 tweets collected.
#
# 813910438903693312 done! in 0.20 seconds
# 481 tweets collected.
#
# 813812741911748608 done! in 0.17 seconds
# 482 tweets collected.
#
# 813800681631023104 done! in 0.25 seconds
# 483 tweets collected.
#
# 813217897535406080 done! in 0.17 seconds
# 484 tweets collected.
#
# 813202720496779264 done! in 0.41 seconds
# 485 tweets collected.
#
# 813187593374461952 done! in 0.19 seconds
# 486 tweets collected.
#
# 813172488309972993 done! in 0.19 seconds
# 487 tweets collected.
#
# 813157409116065792 done! in 0.17 seconds
# 488 tweets collected.
#
# 813142292504645637 done! in 0.19 seconds
# 489 tweets collected.
#
# 813130366689148928 done! in 0.19 seconds
# 490 tweets collected.
#
# 813127251579564032 done! in 0.20 seconds
# 491 tweets collected.
#
# 813112105746448384 done! in 0.19 seconds
# 492 tweets collected.
#
# 813096984823349248 done! in 0.17 seconds
# 493 tweets collected.
#
# 813081950185472002 done! in 0.19 seconds
# 494 tweets collected.
#
# 813066809284972545 done! in 0.17 seconds
# 495 tweets collected.
#
# 813051746834595840 done! in 0.19 seconds
# 496 tweets collected.
#
# 812781120811126785 done! in 0.17 seconds
# 497 tweets collected.
#
# 812747805718642688 done! in 0.19 seconds
# 498 tweets collected.
#
# 812709060537683968 done! in 0.19 seconds
# 499 tweets collected.
#
# 812503143955202048 done! in 0.19 seconds
# 500 tweets collected.
#
# 812466873996607488 done! in 0.19 seconds
# 501 tweets collected.
#
# 812372279581671427 done! in 0.17 seconds
# 502 tweets collected.
#
# 811985624773361665 done! in 0.19 seconds
# 503 tweets collected.
#
# 811744202451197953 done! in 0.23 seconds
# 504 tweets collected.
#
# 811647686436880384 done! in 0.17 seconds
# 505 tweets collected.
#
# 811627233043480576 done! in 0.16 seconds
# 506 tweets collected.
#
# 811386762094317568 done! in 0.19 seconds
# 507 tweets collected.
#
# 810984652412424192 done! in 0.19 seconds
# 508 tweets collected.
#
# 810896069567610880 done! in 0.17 seconds
# 509 tweets collected.
#
# 810657578271330305 done! in 0.17 seconds
# 510 tweets collected.
#
# 810284430598270976 done! in 0.20 seconds
# 511 tweets collected.
#
# 810254108431155201 done! in 0.19 seconds
# 512 tweets collected.
# 809920764300447744 done! in 0.20 seconds
# 513 tweets collected.
#
# 809808892968534016 done! in 0.19 seconds
# 514 tweets collected.
#
# 809448704142938112 done! in 0.19 seconds
# 515 tweets collected.
#
# 809220051211603969 done! in 0.20 seconds
# 516 tweets collected.
#
# 809084759137812480 done! in 0.16 seconds
# 517 tweets collected.
#
# 808838249661788160 done! in 0.17 seconds
# 518 tweets collected.
#
# 808733504066486276 done! in 0.19 seconds
# 519 tweets collected.
#
# 808501579447930884 done! in 0.22 seconds
# 520 tweets collected.
#
# 808344865868283904 done! in 0.19 seconds
# 521 tweets collected.
#
# 808134635716833280 done! in 0.20 seconds
# 522 tweets collected.
#
# 808106460588765185 done! in 0.19 seconds
# 523 tweets collected.
#
# 808001312164028416 done! in 0.21 seconds
# 524 tweets collected.
#
# 807621403335917568 done! in 0.20 seconds
# 525 tweets collected.
#
# 807106840509214720 done! in 0.18 seconds
# 526 tweets collected.
#
# 807059379405148160 done! in 0.28 seconds
# 527 tweets collected.
#
# 807010152071229440 done! in 0.20 seconds
# 528 tweets collected.
#
# 806629075125202948 done! in 0.30 seconds
# 529 tweets collected.
#
# 806620845233815552 done! in 0.20 seconds
# 530 tweets collected.
#
# 806576416489959424 done! in 0.19 seconds
# 531 tweets collected.
#
# 806542213899489280 done! in 0.19 seconds
# 532 tweets collected.
#
# 806242860592926720 done! in 0.19 seconds
# 533 tweets collected.
#
# 806219024703037440 done! in 0.22 seconds
# 534 tweets collected.
#
# 805958939288408065 done! in 0.17 seconds
# 535 tweets collected.
#
# 805932879469572096 done! in 0.22 seconds
# 536 tweets collected.
#
# 805826884734976000 done! in 0.17 seconds
# 537 tweets collected.
#
# 805823200554876929 done! in 0.20 seconds
# 538 tweets collected.
#
# 805520635690676224 done! in 0.17 seconds
# 539 tweets collected.
#
# 805487436403003392 done! in 0.20 seconds
# 540 tweets collected.
#
# 805207613751304193 done! in 0.20 seconds
# 541 tweets collected.
#
# 804738756058218496 done! in 0.20 seconds
# 542 tweets collected.
#
# 804475857670639616 done! in 0.19 seconds
# 543 tweets collected.
#
# 804413760345620481 done! in 0.20 seconds
# 544 tweets collected.
#
# 804026241225523202 done! in 0.16 seconds
# 545 tweets collected.
#
# 803773340896923648 done! in 0.19 seconds
# 546 tweets collected.
#
# 803692223237865472 done! in 0.19 seconds
# 547 tweets collected.
#
# 803638050916102144 done! in 0.22 seconds
# 548 tweets collected.
#
# 803380650405482500 done! in 0.17 seconds
# 549 tweets collected.
#
# 803321560782307329 done! in 0.22 seconds
# 550 tweets collected.
#
# 803276597545603072 done! in 0.19 seconds
# 551 tweets collected.
#
# 802952499103731712 done! in 0.19 seconds
# 552 tweets collected.
#
# 802624713319034886 done! in 0.20 seconds
# 553 tweets collected.
#
# 802600418706604034 done! in 0.17 seconds
# 554 tweets collected.
#
# 802572683846291456 done! in 0.20 seconds
# 555 tweets collected.
#
# 802323869084381190 done! in 0.20 seconds
# 556 tweets collected.
#
# 802265048156610565 done! in 0.19 seconds
# 557 tweets collected.
#
# No status found with that ID # 802247111496568832
#
# 802239329049477120 done! in 0.17 seconds
# 558 tweets collected.
#
# 802185808107208704 done! in 0.19 seconds
# 559 tweets collected.
#
# 801958328846974976 done! in 0.19 seconds
# 560 tweets collected.
#
# 801854953262350336 done! in 0.19 seconds
# 561 tweets collected.
#
# 801538201127157760 done! in 0.19 seconds
# 562 tweets collected.
#
# 801285448605831168 done! in 0.17 seconds
# 563 tweets collected.
#
# 801167903437357056 done! in 0.20 seconds
# 564 tweets collected.
#
# 801127390143516673 done! in 0.17 seconds
# 565 tweets collected.
#
# 801115127852503040 done! in 0.17 seconds
# 566 tweets collected.
#
# 800859414831898624 done! in 0.17 seconds
# 567 tweets collected.
#
# 800855607700029440 done! in 0.22 seconds
# 568 tweets collected.
#
# 800751577355128832 done! in 0.17 seconds
# 569 tweets collected.
#
# 800513324630806528 done! in 0.17 seconds
# 570 tweets collected.
#
# 800459316964663297 done! in 0.17 seconds
# 571 tweets collected.
#
# 800443802682937345 done! in 0.20 seconds
# 572 tweets collected.
#
# 800388270626521089 done! in 0.19 seconds
# 573 tweets collected.
#
# 800188575492947969 done! in 0.19 seconds
# 574 tweets collected.
#
# 800141422401830912 done! in 0.17 seconds
# 575 tweets collected.
#
# 800018252395122689 done! in 0.19 seconds
# 576 tweets collected.
#
# 799774291445383169 done! in 0.23 seconds
# 577 tweets collected.
#
# 799757965289017345 done! in 0.17 seconds
# 578 tweets collected.
#
# 799422933579902976 done! in 0.27 seconds
# 579 tweets collected.
#
# 799308762079035393 done! in 0.20 seconds
# 580 tweets collected.
#
# 799297110730567681 done! in 0.16 seconds
# 581 tweets collected.
#
# 799063482566066176 done! in 0.17 seconds
# 582 tweets collected.
#
# 798933969379225600 done! in 0.17 seconds
# 583 tweets collected.
#
# 798925684722855936 done! in 0.22 seconds
# 584 tweets collected.
#
# 798705661114773508 done! in 0.20 seconds
# 585 tweets collected.
#
# 798701998996647937 done! in 0.17 seconds
# 586 tweets collected.
#
# 798697898615730177 done! in 0.17 seconds
# 587 tweets collected.
#
# 798694562394996736 done! in 0.20 seconds
# 588 tweets collected.
#
# 798686750113755136 done! in 0.17 seconds
# 589 tweets collected.
#
# 798682547630837760 done! in 0.23 seconds
# 590 tweets collected.
#
# 798673117451325440 done! in 0.18 seconds
# 591 tweets collected.
#
# 798665375516884993 done! in 0.19 seconds
# 592 tweets collected.
#
# 798644042770751489 done! in 0.17 seconds
# 593 tweets collected.
#
# 798628517273620480 done! in 0.20 seconds
# 594 tweets collected.
#
# 798585098161549313 done! in 0.19 seconds
# 595 tweets collected.
#
# 798576900688019456 done! in 0.20 seconds
# 596 tweets collected.
#
# 798340744599797760 done! in 0.17 seconds
# 597 tweets collected.
#
# 798209839306514432 done! in 0.19 seconds
# 598 tweets collected.
#
# 797971864723324932 done! in 0.17 seconds
# 599 tweets collected.
#
# 797545162159308800 done! in 0.20 seconds
# 600 tweets collected.
#
# 797236660651966464 done! in 0.27 seconds
# 601 tweets collected.
#
# 797165961484890113 done! in 0.22 seconds
# 602 tweets collected.
#
# 796904159865868288 done! in 0.17 seconds
# 603 tweets collected.
#
# 796865951799083009 done! in 0.19 seconds
# 604 tweets collected.
#
# 796759840936919040 done! in 0.20 seconds
# 605 tweets collected.
#
# 796563435802726400 done! in 0.17 seconds
# 606 tweets collected.
#
# 796484825502875648 done! in 0.17 seconds
# 607 tweets collected.
#
# 796387464403357696 done! in 0.19 seconds
# 608 tweets collected.
#
# 796177847564038144 done! in 0.20 seconds
# 609 tweets collected.
#
# 796149749086875649 done! in 0.17 seconds
# 610 tweets collected.
#
# 796125600683540480 done! in 0.17 seconds
# 611 tweets collected.
#
# 796116448414461957 done! in 0.17 seconds
# 612 tweets collected.
#
# 796080075804475393 done! in 0.22 seconds
# 613 tweets collected.
#
# 796031486298386433 done! in 0.20 seconds
# 614 tweets collected.
#
# 795464331001561088 done! in 0.22 seconds
# 615 tweets collected.
#
# 795400264262053889 done! in 0.20 seconds
# 616 tweets collected.
#
# 795076730285391872 done! in 0.17 seconds
# 617 tweets collected.
#
# 794983741416415232 done! in 0.20 seconds
# 618 tweets collected.
#
# 794926597468000259 done! in 0.20 seconds
# 619 tweets collected.
#
# 794355576146903043 done! in 0.19 seconds
# 620 tweets collected.
#
# 794332329137291264 done! in 0.23 seconds
# 621 tweets collected.
#
# 794205286408003585 done! in 0.17 seconds
# 622 tweets collected.
#
# 793962221541933056 done! in 0.19 seconds
# 623 tweets collected.
#
# 793845145112371200 done! in 0.17 seconds
# 624 tweets collected.
#
# 793614319594401792 done! in 0.19 seconds
# 625 tweets collected.
#
# 793601777308463104 done! in 0.17 seconds
# 626 tweets collected.
#
# 793500921481273345 done! in 0.20 seconds
# 627 tweets collected.
#
# 793286476301799424 done! in 0.16 seconds
# 628 tweets collected.
#
# 793271401113350145 done! in 0.20 seconds
# 629 tweets collected.
#
# 793256262322548741 done! in 0.20 seconds
# 630 tweets collected.
#
# 793241302385262592 done! in 0.19 seconds
# 631 tweets collected.
#
# 793226087023144960 done! in 0.17 seconds
# 632 tweets collected.
#
# 793210959003287553 done! in 0.20 seconds
# 633 tweets collected.
#
# 793195938047070209 done! in 0.19 seconds
# 634 tweets collected.
#
# 793180763617361921 done! in 0.19 seconds
# 635 tweets collected.
#
# 793165685325201412 done! in 0.16 seconds
# 636 tweets collected.
#
# 793150605191548928 done! in 0.19 seconds
# 637 tweets collected.
#
# 793135492858580992 done! in 0.19 seconds
# 638 tweets collected.
#
# 793120401413079041 done! in 0.16 seconds
# 639 tweets collected.
#
# 792913359805018113 done! in 0.19 seconds
# 640 tweets collected.
# 792883833364439040 done! in 0.20 seconds
# 641 tweets collected.
#
# 792773781206999040 done! in 0.23 seconds
# 642 tweets collected.
#
# 792394556390137856 done! in 0.20 seconds
# 643 tweets collected.
#
# 792050063153438720 done! in 0.20 seconds
# 644 tweets collected.
#
# 791821351946420224 done! in 0.22 seconds
# 645 tweets collected.
#
# 791784077045166082 done! in 0.21 seconds
# 646 tweets collected.
#
# 791780927877898241 done! in 0.25 seconds
# 647 tweets collected.
#
# 791774931465953280 done! in 0.20 seconds
# 648 tweets collected.
#
# 791672322847637504 done! in 0.19 seconds
# 649 tweets collected.
#
# 791406955684368384 done! in 0.18 seconds
# 650 tweets collected.
#
# 791312159183634433 done! in 0.17 seconds
# 651 tweets collected.
#
# 791026214425268224 done! in 0.20 seconds
# 652 tweets collected.
#
# 790987426131050500 done! in 0.19 seconds
# 653 tweets collected.
#
# 790946055508652032 done! in 0.18 seconds
# 654 tweets collected.
#
# 790723298204217344 done! in 0.22 seconds
# 655 tweets collected.
#
# 790698755171364864 done! in 0.18 seconds
# 656 tweets collected.
#
# 790581949425475584 done! in 0.19 seconds
# 657 tweets collected.
#
# 790337589677002753 done! in 0.17 seconds
# 658 tweets collected.
#
# 790277117346975746 done! in 0.20 seconds
# 659 tweets collected.
#
# 790227638568808452 done! in 0.17 seconds
# 660 tweets collected.
#
# 789986466051088384 done! in 0.21 seconds
# 661 tweets collected.
#
# 789960241177853952 done! in 0.19 seconds
# 662 tweets collected.
#
# 789903600034189313 done! in 0.19 seconds
# 663 tweets collected.
#
# 789628658055020548 done! in 0.21 seconds
# 664 tweets collected.
#
# 789599242079838210 done! in 0.19 seconds
# 665 tweets collected.
#
# 789530877013393408 done! in 0.20 seconds
# 666 tweets collected.
#
# 789314372632018944 done! in 0.19 seconds
# 667 tweets collected.
#
# 789280767834746880 done! in 0.17 seconds
# 668 tweets collected.
#
# 789268448748703744 done! in 0.16 seconds
# 669 tweets collected.
#
# 789137962068021249 done! in 0.21 seconds
# 670 tweets collected.
#
# 788908386943430656 done! in 0.20 seconds
# 671 tweets collected.
#
# 788765914992902144 done! in 0.20 seconds
# 672 tweets collected.
#
# 788552643979468800 done! in 0.17 seconds
# 673 tweets collected.
#
# 788412144018661376 done! in 0.19 seconds
# 674 tweets collected.
#
# 788178268662984705 done! in 0.17 seconds
# 675 tweets collected.
#
# 788150585577050112 done! in 0.16 seconds
# 676 tweets collected.
#
# 788070120937619456 done! in 0.18 seconds
# 677 tweets collected.
#
# 788039637453406209 done! in 0.17 seconds
# 678 tweets collected.
#
# 787810552592695296 done! in 0.19 seconds
# 679 tweets collected.
#
# 787717603741622272 done! in 0.17 seconds
# 680 tweets collected.
#
# 787397959788929025 done! in 0.18 seconds
# 681 tweets collected.
#
# 787322443945877504 done! in 0.17 seconds
# 682 tweets collected.
#
# 787111942498508800 done! in 0.21 seconds
# 683 tweets collected.
#
# 786963064373534720 done! in 0.16 seconds
# 684 tweets collected.
#
# 786729988674449408 done! in 0.23 seconds
# 685 tweets collected.
#
# 786709082849828864 done! in 0.19 seconds
# 686 tweets collected.
#
# 786664955043049472 done! in 0.21 seconds
# 687 tweets collected.
#
# 786595970293370880 done! in 0.17 seconds
# 688 tweets collected.
#
# 786363235746385920 done! in 0.18 seconds
# 689 tweets collected.
#
# 786286427768250368 done! in 0.19 seconds
# 690 tweets collected.
#
# 786233965241827333 done! in 0.18 seconds
# 691 tweets collected.
#
# 786051337297522688 done! in 0.19 seconds
# 692 tweets collected.
#
# 786036967502913536 done! in 0.20 seconds
# 693 tweets collected.
#
# 785927819176054784 done! in 0.19 seconds
# 694 tweets collected.
#
# 785872687017132033 done! in 0.23 seconds
# 695 tweets collected.
#
# 785639753186217984 done! in 0.17 seconds
# 696 tweets collected.
#
# 785533386513321988 done! in 0.20 seconds
# 697 tweets collected.
#
# 785515384317313025 done! in 0.20 seconds
# 698 tweets collected.
#
# 785264754247995392 done! in 0.17 seconds
# 699 tweets collected.
#
# 785170936622350336 done! in 0.20 seconds
# 700 tweets collected.
#
# 784826020293709826 done! in 0.17 seconds
# 701 tweets collected.
#
# 784517518371221505 done! in 0.18 seconds
# 702 tweets collected.
#
# 784431430411685888 done! in 0.19 seconds
# 703 tweets collected.
#
# 784183165795655680 done! in 0.18 seconds
# 704 tweets collected.
#
# 784057939640352768 done! in 0.17 seconds
# 705 tweets collected.
#
# 783839966405230592 done! in 0.20 seconds
# 706 tweets collected.
#
# 783821107061198850 done! in 0.17 seconds
# 707 tweets collected.
#
# 783695101801398276 done! in 0.17 seconds
# 708 tweets collected.
#
# 783466772167098368 done! in 0.19 seconds
# 709 tweets collected.
#
# 783391753726550016 done! in 0.18 seconds
# 710 tweets collected.
#
# 783347506784731136 done! in 0.21 seconds
# 711 tweets collected.
#
# 783334639985389568 done! in 0.19 seconds
# 712 tweets collected.
#
# 783085703974514689 done! in 0.15 seconds
# 713 tweets collected.
#
# 782969140009107456 done! in 0.19 seconds
# 714 tweets collected.
#
# 782747134529531904 done! in 0.17 seconds
# 715 tweets collected.
#
# 782722598790725632 done! in 0.20 seconds
# 716 tweets collected.
#
# 782598640137187329 done! in 0.17 seconds
# 717 tweets collected.
#
# 782305867769217024 done! in 0.17 seconds
# 718 tweets collected.
#
# 782021823840026624 done! in 0.20 seconds
# 719 tweets collected.
#
# 781955203444699136 done! in 0.19 seconds
# 720 tweets collected.
#
# 781661882474196992 done! in 0.18 seconds
# 721 tweets collected.
#
# 781655249211752448 done! in 0.38 seconds
# 722 tweets collected.
#
# 781524693396357120 done! in 0.19 seconds
# 723 tweets collected.
#
# 781308096455073793 done! in 0.18 seconds
# 724 tweets collected.
#
# 781251288990355457 done! in 0.17 seconds
# 725 tweets collected.
#
# 781163403222056960 done! in 0.20 seconds
# 726 tweets collected.
#
# 780931614150983680 done! in 0.19 seconds
# 727 tweets collected.
#
# 780858289093574656 done! in 0.17 seconds
# 728 tweets collected.
#
# 780800785462489090 done! in 0.19 seconds
# 729 tweets collected.
#
# 780601303617732608 done! in 0.17 seconds
# 730 tweets collected.
#
# 780543529827336192 done! in 0.17 seconds
# 731 tweets collected.
#
# 780496263422808064 done! in 0.21 seconds
# 732 tweets collected.
#
# 780476555013349377 done! in 0.19 seconds
# 733 tweets collected.
#
# 780459368902959104 done! in 0.23 seconds
# 734 tweets collected.
#
# 780192070812196864 done! in 0.16 seconds
# 735 tweets collected.
#
# 780092040432480260 done! in 0.17 seconds
# 736 tweets collected.
#
# 780074436359819264 done! in 0.19 seconds
# 737 tweets collected.
#
# 779834332596887552 done! in 0.18 seconds
# 738 tweets collected.
#
# 779377524342161408 done! in 0.19 seconds
# 739 tweets collected.
#
# 779124354206535695 done! in 0.19 seconds
# 740 tweets collected.
#
# 779123168116150273 done! in 0.19 seconds
# 741 tweets collected.
#
# 779056095788752897 done! in 0.23 seconds
# 742 tweets collected.
#
# 778990705243029504 done! in 0.17 seconds
# 743 tweets collected.
#
# 778774459159379968 done! in 0.17 seconds
# ...
#
# 670433248821026816 done! in 0.19 seconds
# 2104 tweets collected.
#
# 670428280563085312 done! in 0.21 seconds
# 2105 tweets collected.
#
# 670427002554466305 done! in 0.19 seconds
# 2106 tweets collected.
#
# 670421925039075328 done! in 0.23 seconds
# 2107 tweets collected.
#
# 670420569653809152 done! in 0.17 seconds
# 2108 tweets collected.
#
# 670417414769758208 done! in 0.18 seconds
# 2109 tweets collected.
#
# 670411370698022913 done! in 0.21 seconds
# 2110 tweets collected.
#
# 670408998013820928 done! in 0.19 seconds
# 2111 tweets collected.
#
# 670403879788544000 done! in 0.18 seconds
# 2112 tweets collected.
#
# 670385711116361728 done! in 0.19 seconds
# 2113 tweets collected.
#
# 670374371102445568 done! in 0.21 seconds
# 2114 tweets collected.
#
# 670361874861563904 done! in 0.19 seconds
# 2115 tweets collected.
#
# 670338931251150849 done! in 0.18 seconds
# 2116 tweets collected.
#
# 670319130621435904 done! in 0.17 seconds
# 2117 tweets collected.
#
# 670303360680108032 done! in 0.18 seconds
# 2118 tweets collected.
#
# 670290420111441920 done! in 0.21 seconds
# 2119 tweets collected.
#
# 670093938074779648 done! in 0.16 seconds
# 2120 tweets collected.
#
# 670086499208155136 done! in 0.16 seconds
# 2121 tweets collected.
#
# 670079681849372674 done! in 0.17 seconds
# 2122 tweets collected.
#
# 670073503555706880 done! in 0.20 seconds
# 2123 tweets collected.
#
# 670069087419133954 done! in 0.16 seconds
# 2124 tweets collected.
#
# 670061506722140161 done! in 0.23 seconds
# 2125 tweets collected.
#
# 670055038660800512 done! in 0.17 seconds
# 2126 tweets collected.
#
# 670046952931721218 done! in 0.21 seconds
# 2127 tweets collected.
#
# 670040295598354432 done! in 0.20 seconds
# 2128 tweets collected.
#
# 670037189829525505 done! in 0.18 seconds
# 2129 tweets collected.
#
# 670003130994700288 done! in 0.19 seconds
# 2130 tweets collected.
#
# 669993076832759809 done! in 0.17 seconds
# 2131 tweets collected.
#
# 669972011175813120 done! in 0.20 seconds
# 2132 tweets collected.
#
# 669970042633789440 done! in 0.20 seconds
# 2133 tweets collected.
#
# 669942763794931712 done! in 0.17 seconds
# 2134 tweets collected.
#
# 669926384437997569 done! in 0.21 seconds
# 2135 tweets collected.
#
# 669923323644657664 done! in 0.17 seconds
# 2136 tweets collected.
#
# 669753178989142016 done! in 0.17 seconds
# 2137 tweets collected.
#
# 669749430875258880 done! in 0.17 seconds
# 2138 tweets collected.
#
# 669684865554620416 done! in 0.18 seconds
# 2139 tweets collected.
#
# 669683899023405056 done! in 0.19 seconds
# 2140 tweets collected.
#
# 669682095984410625 done! in 0.20 seconds
# 2141 tweets collected.
#
# 669680153564442624 done! in 0.17 seconds
# 2142 tweets collected.
#
# 669661792646373376 done! in 0.22 seconds
# 2143 tweets collected.
#
# 669625907762618368 done! in 0.23 seconds
# 2144 tweets collected.
#
# 669603084620980224 done! in 0.19 seconds
# 2145 tweets collected.
#
# 669597912108789760 done! in 0.21 seconds
# 2146 tweets collected.
#
# 669583744538451968 done! in 0.20 seconds
# 2147 tweets collected.
#
# 669573570759163904 done! in 0.18 seconds
# 2148 tweets collected.
#
# 669571471778410496 done! in 0.17 seconds
# 2149 tweets collected.
#
# 669567591774625800 done! in 0.17 seconds
# 2150 tweets collected.
#
# 669564461267722241 done! in 0.20 seconds
# 2151 tweets collected.
#
# 669393256313184256 done! in 0.20 seconds
# 2152 tweets collected.
#
# 669375718304980992 done! in 0.18 seconds
# 2153 tweets collected.
#
# 669371483794317312 done! in 0.20 seconds
# 2154 tweets collected.
#
# 669367896104181761 done! in 0.19 seconds
# 2155 tweets collected.
#
# 669363888236994561 done! in 0.18 seconds
# 2156 tweets collected.
#
# 669359674819481600 done! in 0.17 seconds
# 2157 tweets collected.
#
# 669354382627049472 done! in 0.16 seconds
# 2158 tweets collected.
#
# 669353438988365824 done! in 0.17 seconds
# 2159 tweets collected.
#
# 669351434509529089 done! in 0.18 seconds
# 2160 tweets collected.
#
# 669328503091937280 done! in 0.17 seconds
# 2161 tweets collected.
#
# 669327207240699904 done! in 0.19 seconds
# 2162 tweets collected.
#
# 669324657376567296 done! in 0.17 seconds
# 2163 tweets collected.
#
# 669216679721873412 done! in 0.16 seconds
# 2164 tweets collected.
#
# 669214165781868544 done! in 0.17 seconds
# 2165 tweets collected.
#
# 669203728096960512 done! in 0.21 seconds
# 2166 tweets collected.
#
# 669037058363662336 done! in 0.19 seconds
# 2167 tweets collected.
#
# 669015743032369152 done! in 0.20 seconds
# 2168 tweets collected.
#
# 669006782128353280 done! in 0.19 seconds
# 2169 tweets collected.
# 669000397445533696 done! in 0.17 seconds
# 2170 tweets collected.
#
# 668994913074286592 done! in 0.21 seconds
# 2171 tweets collected.
#
# 668992363537309700 done! in 0.19 seconds
# 2172 tweets collected.
#
# 668989615043424256 done! in 0.18 seconds
# 2173 tweets collected.
#
# 668988183816871936 done! in 0.17 seconds
# 2174 tweets collected.
#
# 668986018524233728 done! in 0.18 seconds
# 2175 tweets collected.
#
# 668981893510119424 done! in 0.21 seconds
# 2176 tweets collected.
#
# 668979806671884288 done! in 0.21 seconds
# 2177 tweets collected.
#
# 668975677807423489 done! in 0.19 seconds
# 2178 tweets collected.
#
# 668967877119254528 done! in 0.18 seconds
# 2179 tweets collected.
#
# 668960084974809088 done! in 0.19 seconds
# 2180 tweets collected.
#
# 668955713004314625 done! in 0.23 seconds
# 2181 tweets collected.
#
# 668932921458302977 done! in 0.17 seconds
# 2182 tweets collected.
#
# 668902994700836864 done! in 0.16 seconds
# 2183 tweets collected.
#
# 668892474547511297 done! in 0.19 seconds
# 2184 tweets collected.
#
# 668872652652679168 done! in 0.15 seconds
# 2185 tweets collected.
#
# 668852170888998912 done! in 0.20 seconds
# 2186 tweets collected.
#
# 668826086256599040 done! in 0.20 seconds
# 2187 tweets collected.
#
# 668815180734689280 done! in 0.21 seconds
# 2188 tweets collected.
#
# 668779399630725120 done! in 0.21 seconds
# 2189 tweets collected.
#
# 668655139528511488 done! in 0.18 seconds
# 2190 tweets collected.
#
# 668645506898350081 done! in 0.21 seconds
# 2191 tweets collected.
#
# 668643542311546881 done! in 0.17 seconds
# 2192 tweets collected.
#
# 668641109086707712 done! in 0.20 seconds
# 2193 tweets collected.
#
# 668636665813057536 done! in 0.21 seconds
# 2194 tweets collected.
#
# 668633411083464705 done! in 0.22 seconds
# 2195 tweets collected.
#
# 668631377374486528 done! in 0.18 seconds
# 2196 tweets collected.
#
# 668627278264475648 done! in 0.17 seconds
# 2197 tweets collected.
#
# 668625577880875008 done! in 0.17 seconds
# 2198 tweets collected.
#
# 668623201287675904 done! in 0.18 seconds
# 2199 tweets collected.
#
# 668620235289837568 done! in 0.19 seconds
# 2200 tweets collected.
#
# 668614819948453888 done! in 0.20 seconds
# 2201 tweets collected.
#
# 668587383441514497 done! in 0.17 seconds
# 2202 tweets collected.
#
# 668567822092664832 done! in 0.21 seconds
# 2203 tweets collected.
#
# 668544745690562560 done! in 0.19 seconds
# 2204 tweets collected.
#
# 668542336805281792 done! in 0.16 seconds
# 2205 tweets collected.
#
# 668537837512433665 done! in 0.19 seconds
# 2206 tweets collected.
#
# 668528771708952576 done! in 0.17 seconds
# 2207 tweets collected.
#
# 668507509523615744 done! in 0.21 seconds
# 2208 tweets collected.
#
# 668496999348633600 done! in 0.20 seconds
# 2209 tweets collected.
#
# 668484198282485761 done! in 0.21 seconds
# 2210 tweets collected.
#
# 668480044826800133 done! in 0.19 seconds
# 2211 tweets collected.
#
# 668466899341221888 done! in 0.17 seconds
# 2212 tweets collected.
#
# 668297328638447616 done! in 0.19 seconds
# 2213 tweets collected.
#
# 668291999406125056 done! in 0.20 seconds
# 2214 tweets collected.
#
# 668286279830867968 done! in 0.19 seconds
# 2215 tweets collected.
#
# 668274247790391296 done! in 0.20 seconds
# 2216 tweets collected.
#
# 668268907921326080 done! in 0.21 seconds
# 2217 tweets collected.
#
# 668256321989451776 done! in 0.17 seconds
# 2218 tweets collected.
#
# 668248472370458624 done! in 0.17 seconds
# 2219 tweets collected.
#
# 668237644992782336 done! in 0.23 seconds
# 2220 tweets collected.
#
# 668226093875376128 done! in 0.17 seconds
# 2221 tweets collected.
#
# 668221241640230912 done! in 0.18 seconds
# 2222 tweets collected.
#
# 668204964695683073 done! in 0.17 seconds
# 2223 tweets collected.
#
# 668190681446379520 done! in 0.17 seconds
# 2224 tweets collected.
#
# 668171859951755264 done! in 0.19 seconds
# 2225 tweets collected.
#
# 668154635664932864 done! in 0.18 seconds
# 2226 tweets collected.
#
# 668142349051129856 done! in 0.17 seconds
# 2227 tweets collected.
#
# 668113020489474048 done! in 0.52 seconds
# 2228 tweets collected.
#
# 667937095915278337 done! in 0.19 seconds
# 2229 tweets collected.
#
# 667924896115245057 done! in 0.18 seconds
# 2230 tweets collected.
#
# 667915453470232577 done! in 0.17 seconds
# 2231 tweets collected.
#
# 667911425562669056 done! in 0.20 seconds
# 2232 tweets collected.
#
# 667902449697558528 done! in 0.31 seconds
# 2233 tweets collected.
#
# 667886921285246976 done! in 0.19 seconds
# 2234 tweets collected.
#
# 667885044254572545 done! in 0.15 seconds
# 2235 tweets collected.
#
# 667878741721415682 done! in 0.19 seconds
# 2236 tweets collected.
#
# 667873844930215936 done! in 0.18 seconds
# 2237 tweets collected.
#
# 667866724293877760 done! in 0.20 seconds
# 2238 tweets collected.
#
# 667861340749471744 done! in 0.17 seconds
# 2239 tweets collected.
#
# 667832474953625600 done! in 0.19 seconds
# 2240 tweets collected.
#
# 667806454573760512 done! in 0.18 seconds
# 2241 tweets collected.
#
# 667801013445750784 done! in 0.17 seconds
# 2242 tweets collected.
#
# 667793409583771648 done! in 0.23 seconds
# 2243 tweets collected.
#
# 667782464991965184 done! in 0.17 seconds
# 2244 tweets collected.
#
# 667773195014021121 done! in 0.21 seconds
# 2245 tweets collected.
#
# 667766675769573376 done! in 0.19 seconds
# 2246 tweets collected.
#
# 667728196545200128 done! in 0.18 seconds
# 2247 tweets collected.
#
# 667724302356258817 done! in 0.17 seconds
# 2248 tweets collected.
#
# 667550904950915073 done! in 0.20 seconds
# 2249 tweets collected.
#
# 667550882905632768 done! in 0.24 seconds
# 2250 tweets collected.
#
# 667549055577362432 done! in 0.17 seconds
# 2251 tweets collected.
#
# 667546741521195010 done! in 0.20 seconds
# 2252 tweets collected.
#
# 667544320556335104 done! in 0.17 seconds
# 2253 tweets collected.
#
# 667538891197542400 done! in 0.21 seconds
# 2254 tweets collected.
#
# 667534815156183040 done! in 0.19 seconds
# 2255 tweets collected.
#
# 667530908589760512 done! in 0.24 seconds
# 2256 tweets collected.
#
# 667524857454854144 done! in 0.17 seconds
# 2257 tweets collected.
#
# 667517642048163840 done! in 0.17 seconds
# 2258 tweets collected.
#
# 667509364010450944 done! in 0.19 seconds
# 2259 tweets collected.
#
# 667502640335572993 done! in 0.17 seconds
# 2260 tweets collected.
#
# 667495797102141441 done! in 0.16 seconds
# 2261 tweets collected.
#
# 667491009379606528 done! in 0.17 seconds
# 2262 tweets collected.
#
# 667470559035432960 done! in 0.17 seconds
# 2263 tweets collected.
#
# 667455448082227200 done! in 0.22 seconds
# 2264 tweets collected.
#
# 667453023279554560 done! in 0.21 seconds
# 2265 tweets collected.
#
# 667443425659232256 done! in 0.16 seconds
# 2266 tweets collected.
#
# 667437278097252352 done! in 0.18 seconds
# 2267 tweets collected.
#
# 667435689202614272 done! in 0.21 seconds
# 2268 tweets collected.
#
# 667405339315146752 done! in 0.17 seconds
# 2269 tweets collected.
#
# 667393430834667520 done! in 0.26 seconds
# 2270 tweets collected.
#
# 667369227918143488 done! in 0.16 seconds
# 2271 tweets collected.
#
# 667211855547486208 done! in 0.19 seconds
# 2272 tweets collected.
#
# 667200525029539841 done! in 0.16 seconds
# 2273 tweets collected.
#
# 667192066997374976 done! in 0.20 seconds
# 2274 tweets collected.
#
# 667188689915760640 done! in 0.19 seconds
# 2275 tweets collected.
#
# 667182792070062081 done! in 0.20 seconds
# 2276 tweets collected.
#
# 667177989038297088 done! in 0.16 seconds
# 2277 tweets collected.
#
# 667176164155375616 done! in 0.18 seconds
# 2278 tweets collected.
#
# 667174963120574464 done! in 0.19 seconds
# 2279 tweets collected.
#
# 667171260800061440 done! in 0.18 seconds
# 2280 tweets collected.
#
# 667165590075940865 done! in 0.17 seconds
# 2281 tweets collected.
#
# 667160273090932737 done! in 0.17 seconds
# 2282 tweets collected.
#
# 667152164079423490 done! in 0.19 seconds
# 2283 tweets collected.
#
# 667138269671505920 done! in 0.17 seconds
# 2284 tweets collected.
#
# 667119796878725120 done! in 0.21 seconds
# 2285 tweets collected.
#
# 667090893657276420 done! in 0.21 seconds
# 2286 tweets collected.
#
# 667073648344346624 done! in 0.16 seconds
# 2287 tweets collected.
#
# 667070482143944705 done! in 0.17 seconds
# 2288 tweets collected.
#
# 667065535570550784 done! in 0.21 seconds
# 2289 tweets collected.
#
# 667062181243039745 done! in 0.17 seconds
# 2290 tweets collected.
#
# 667044094246576128 done! in 0.20 seconds
# 2291 tweets collected.
#
# 667012601033924608 done! in 0.19 seconds
# 2292 tweets collected.
#
# 666996132027977728 done! in 0.18 seconds
# 2293 tweets collected.
#
# 666983947667116034 done! in 0.23 seconds
# 2294 tweets collected.
#
# 666837028449972224 done! in 0.17 seconds
# 2295 tweets collected.
#
# 666835007768551424 done! in 0.20 seconds
# 2296 tweets collected.
#
# 666826780179869698 done! in 0.17 seconds
# 2297 tweets collected.
# 666817836334096384 done! in 0.16 seconds
# 2298 tweets collected.
#
# 666804364988780544 done! in 0.20 seconds
# 2299 tweets collected.
#
# 666786068205871104 done! in 0.17 seconds
# 2300 tweets collected.
#
# 666781792255496192 done! in 0.17 seconds
# 2301 tweets collected.
#
# 666776908487630848 done! in 0.20 seconds
# 2302 tweets collected.
#
# 666739327293083650 done! in 0.19 seconds
# 2303 tweets collected.
#
# 666701168228331520 done! in 0.18 seconds
# 2304 tweets collected.
#
# 666691418707132416 done! in 0.16 seconds
# 2305 tweets collected.
#
# 666649482315059201 done! in 0.18 seconds
# 2306 tweets collected.
#
# 666644823164719104 done! in 0.21 seconds
# 2307 tweets collected.
#
# 666454714377183233 done! in 0.23 seconds
# 2308 tweets collected.
#
# 666447344410484738 done! in 0.19 seconds
# 2309 tweets collected.
#
# 666437273139982337 done! in 0.18 seconds
# 2310 tweets collected.
#
# 666435652385423360 done! in 0.19 seconds
# 2311 tweets collected.
#
# 666430724426358785 done! in 0.18 seconds
# 2312 tweets collected.
#
# 666428276349472768 done! in 0.17 seconds
# 2313 tweets collected.
#
# 666421158376562688 done! in 0.16 seconds
# 2314 tweets collected.
#
# 666418789513326592 done! in 0.19 seconds
# 2315 tweets collected.
#
# 666411507551481857 done! in 0.18 seconds
# 2316 tweets collected.
#
# 666407126856765440 done! in 0.20 seconds
# 2317 tweets collected.
#
# 666396247373291520 done! in 0.21 seconds
# 2318 tweets collected.
#
# 666373753744588802 done! in 0.21 seconds
# 2319 tweets collected.
#
# 666362758909284353 done! in 0.17 seconds
# 2320 tweets collected.
#
# 666353288456101888 done! in 0.20 seconds
# 2321 tweets collected.
#
# 666345417576210432 done! in 0.19 seconds
# 2322 tweets collected.
#
# 666337882303524864 done! in 0.24 seconds
# 2323 tweets collected.
#
# 666293911632134144 done! in 0.19 seconds
# 2324 tweets collected.
#
# 666287406224695296 done! in 0.20 seconds
# 2325 tweets collected.
#
# 666273097616637952 done! in 0.16 seconds
# 2326 tweets collected.
#
# 666268910803644416 done! in 0.18 seconds
# 2327 tweets collected.
#
# 666104133288665088 done! in 0.23 seconds
# 2328 tweets collected.
#
# 666102155909144576 done! in 0.19 seconds
# 2329 tweets collected.
#
# 666099513787052032 done! in 0.18 seconds
# 2330 tweets collected.
#
# 666094000022159362 done! in 0.19 seconds
# 2331 tweets collected.
#
# 666082916733198337 done! in 0.17 seconds
# 2332 tweets collected.
#
# 666073100786774016 done! in 0.17 seconds
# 2333 tweets collected.
#
# 666071193221509120 done! in 0.20 seconds
# 2334 tweets collected.
#
# 666063827256086533 done! in 0.16 seconds
# 2335 tweets collected.
#
# 666058600524156928 done! in 0.18 seconds
# 2336 tweets collected.
#
# 666057090499244032 done! in 0.19 seconds
# 2337 tweets collected.
#
# 666055525042405380 done! in 0.18 seconds
# 2338 tweets collected.
#
# 666051853826850816 done! in 0.19 seconds
# 2339 tweets collected.
#
# 666050758794694657 done! in 0.17 seconds
# 2340 tweets collected.
#
# 666049248165822465 done! in 0.20 seconds
# 2341 tweets collected.
#
# 666044226329800704 done! in 0.20 seconds
# 2342 tweets collected.
#
# 666033412701032449 done! in 0.17 seconds
# 2343 tweets collected.
#
# 666029285002620928 done! in 0.18 seconds
# 2344 tweets collected.
#
# 666020888022790149 done! in 0.20 seconds
# 2345 tweets collected.
#
# The following twitter id's were not found:
# [888202515573088257, 873697596434513921, 869988702071779329, 866816280283807744, 861769973181624320, 845459076796616705, 842892208864923648, 837012587749474308, 827228250799742977, 802247111496568832, 775096608509886464]

# %%
# in case the above cell was not run
not_found = [888202515573088257, 873697596434513921, 869988702071779329, 
             866816280283807744, 861769973181624320, 845459076796616705, 
             842892208864923648, 837012587749474308, 827228250799742977, 
             802247111496568832, 775096608509886464]

# %% [markdown]
# # Assessing Data

# %%
# load downloaded files into pandas dataframes
predict = pd.read_csv("image_prediction.tsv", sep='\t')
tweet_data = pd.read_json('tweet_json.txt', lines=True)
# get only id, retweet_count, favorite_count
tweet_data = tweet_data[['id', 'retweet_count', 'favorite_count']]

# %% [markdown]
# #### Let's take a look at our data

# %%
twi_arch.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
# tweet_id                      2356 non-null int64
# in_reply_to_status_id         78 non-null float64
# in_reply_to_user_id           78 non-null float64
# timestamp                     2356 non-null object
# source                        2356 non-null object
# text                          2356 non-null object
# retweeted_status_id           181 non-null float64
# retweeted_status_user_id      181 non-null float64
# retweeted_status_timestamp    181 non-null object
# expanded_urls                 2297 non-null object
# rating_numerator              2356 non-null int64
# rating_denominator            2356 non-null int64
# name                          2356 non-null object
# doggo                         2356 non-null object
# floofer                       2356 non-null object
# pupper                        2356 non-null object
# puppo                         2356 non-null object
# dtypes: float64(4), int64(3), object(10)
# memory usage: 313.0+ KB

# %%
twi_arch.describe()
# Out:
#            tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# count  2.356000e+03           7.800000e+01         7.800000e+01
# mean   7.427716e+17           7.455079e+17         2.014171e+16
# std    6.856705e+16           7.582492e+16         1.252797e+17
# min    6.660209e+17           6.658147e+17         1.185634e+07
# 25%    6.783989e+17           6.757419e+17         3.086374e+08
# 50%    7.196279e+17           7.038708e+17         4.196984e+09
# 75%    7.993373e+17           8.257804e+17         4.196984e+09
# max    8.924206e+17           8.862664e+17         8.405479e+17
#
#        retweeted_status_id  retweeted_status_user_id  rating_numerator  \
# count         1.810000e+02              1.810000e+02       2356.000000
# mean          7.720400e+17              1.241698e+16         13.126486
# std           6.236928e+16              9.599254e+16         45.876648
# min           6.661041e+17              7.832140e+05          0.000000
# 25%           7.186315e+17              4.196984e+09         10.000000
# 50%           7.804657e+17              4.196984e+09         11.000000
# 75%           8.203146e+17              4.196984e+09         12.000000
# max           8.874740e+17              7.874618e+17       1776.000000
#
#        rating_denominator
# count         2356.000000
# mean            10.455433
# std              6.745237
# min              0.000000
# 25%             10.000000
# 50%             10.000000
# 75%             10.000000
# max            170.000000

# %%
twi_arch.timestamp.value_counts()[0:10] # type of data time
# Out:
# 2016-07-02 03:00:36 +0000    1
# 2016-11-20 04:06:37 +0000    1
# 2016-11-06 01:33:58 +0000    1
# 2016-07-26 00:58:34 +0000    1
# 2015-12-30 03:55:29 +0000    1
# 2016-01-21 04:03:58 +0000    1
# 2016-06-25 21:34:37 +0000    1
# 2015-12-11 02:49:59 +0000    1
# 2016-07-12 01:52:49 +0000    1
# 2016-05-07 16:34:32 +0000    1
# Name: timestamp, dtype: int64

# %%
twi_arch.source.value_counts() # source has only four values; categorical variables
# Out:
# <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>     2221
# <a href="http://vine.co" rel="nofollow">Vine - Make a Scene</a>                          91
# <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>                       33
# <a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>      11
# Name: source, dtype: int64

# %%
twi_arch[twi_arch['in_reply_to_status_id'].notnull()] # this means these are replies
# they might still be good
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 30    886267009285017600           8.862664e+17         2.281182e+09
# 55    881633300179243008           8.816070e+17         4.738443e+07
# 64    879674319642796034           8.795538e+17         3.105441e+09
# 113   870726314365509632           8.707262e+17         1.648776e+07
# 148   863427515083354112           8.634256e+17         7.759620e+07
# 149   863079547188785154           6.671522e+17         4.196984e+09
# 179   857214891891077121           8.571567e+17         1.806710e+08
# 184   856526610513747968           8.558181e+17         4.196984e+09
# 186   856288084350160898           8.562860e+17         2.792810e+08
# 188   855862651834028034           8.558616e+17         1.943518e+08
# 189   855860136149123072           8.558585e+17         1.361572e+07
# 218   850333567704068097           8.503288e+17         2.195506e+07
# 228   848213670039564288           8.482121e+17         4.196984e+09
# 234   847617282490613760           8.476062e+17         4.196984e+09
# 251   844979544864018432           7.590995e+17         4.196984e+09
# 274   840698636975636481           8.406983e+17         8.405479e+17
# 290   838150277551247360           8.381455e+17         2.195506e+07
# 291   838085839343206401           8.380855e+17         2.894131e+09
# 313   835246439529840640           8.352460e+17         2.625958e+07
# 342   832088576586297345           8.320875e+17         3.058208e+07
# 346   831926988323639298           8.319030e+17         2.068372e+07
# 387   826598799820865537           8.265984e+17         4.196984e+09
# 409   823333489516937216           8.233264e+17         1.582854e+09
# 427   821153421864615936           8.211526e+17         1.132119e+08
# 498   813130366689148928           8.131273e+17         4.196984e+09
# 513   811647686436880384           8.116272e+17         4.196984e+09
# 565   802265048156610565           7.331095e+17         4.196984e+09
# 857                 12                  10  None  doggo    None    None   None
# 967                 13                  10  None  doggo    None    None   None
# 1005                12                  10  None   None    None  pupper   None
# 1080                13                  10  None   None    None    None   None
# 1295                12                  10  None   None    None    None   None
# 1345                13                  10  None   None    None    None   None
# 1445                10                  10  None   None    None  pupper   None
# 1446                 1                  10  None   None    None    None   None
# 1474                10                  10  None   None    None    None   None
# 1479                11                  10  None   None    None    None   None
# 1497                 9                  10  None   None    None    None   None
# 1523                12                  10  None   None    None    None   None
# 1598                 4                  20  None   None    None    None   None
# 1605                14                  10  None   None    None    None   None
# 1618                 5                  10  None   None    None    None   None
# 1663                20                  16  None   None    None    None   None
# 1689                 5                  10  None   None    None    None   None
# 1774                13                  10  None   None    None    None   None
# 1819                 7                  10  None   None    None    None   None
# 1844                 9                  10  None   None    None    None   None
# 1895                11                  10  None   None    None    None   None
# 1905                13                  10  None   None    None    None   None
# 1914                13                  10  None   None    None    None   None
# 1940                 1                  10  None   None    None    None   None
# 2038                 1                  10  None   None    None    None   None
# 2149                11                  10  None   None    None    None   None
# 2189                12                  10  None   None    None    None   None
# 2298                10                  10  None   None    None    None   None

# %%
twi_arch.text[64] # these are mostly replies
# Out:
# '@RealKentMurphy 14/10 confirmed'

# %%
# check if all missing expanded_urls are in replies
miss_url_id = list(twi_arch[twi_arch['expanded_urls'].isnull()].tweet_id)
replies_id = list(twi_arch[twi_arch['in_reply_to_status_id'].notnull()].tweet_id)

for iden_num in miss_url_id:
    if iden_num not in replies_id:
        print(iden_num)
    else:
        pass
# Out:
# 856330835276025856
# 828361771580813312
# 785515384317313025
# 696518437233913856

# %%
print(replies_id[0:10])
print(miss_url_id[0:10])
twi_arch[twi_arch.name == "Pipsy"]
# Out:
# [886267009285017600, 881633300179243008, 879674319642796034, 870726314365509632, 863427515083354112, 863079547188785154, 857214891891077121, 856526610513747968, 856288084350160898, 855862651834028034]
# [886267009285017600, 881633300179243008, 879674319642796034, 870726314365509632, 863427515083354112, 857214891891077121, 856330835276025856, 856288084350160898, 855862651834028034, 855860136149123072]
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 273   840728873075638272                    NaN                  NaN
# 2293  667152164079423490                    NaN                  NaN
#
#                       timestamp  \
# 273   2017-03-12 00:59:17 +0000
# 2293  2015-11-19 01:27:25 +0000
#
#                                                  source  \
# 273   <a href="http://twitter.com/download/iphone" r...
# 2293  <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  retweeted_status_id  \
# 273   RT @dog_rates: This is Pipsy. He is a fluffbal...         6.671522e+17
# 2293  This is Pipsy. He is a fluffball. Enjoys trave...                  NaN
#
#       retweeted_status_user_id retweeted_status_timestamp  \
# 273               4.196984e+09  2015-11-19 01:27:25 +0000
# 2293                       NaN                        NaN
#
#                                           expanded_urls  rating_numerator  \
# 273   https://twitter.com/dog_rates/status/667152164...                12
# 2293  https://twitter.com/dog_rates/status/667152164...                12
#
#       rating_denominator   name doggo floofer pupper puppo
# 273                   10  Pipsy  None    None   None  None
# 2293                  10  Pipsy  None    None   None  None

# %%
# the four id's above in expanded_urls do not have a picture.
# all rows with no expanded_urls do not have picture

# %%
twi_arch.puppo.value_counts() # need dog stage variable not four columns
# Out:
# None     2326
# puppo      30
# Name: puppo, dtype: int64

# %%
json_id = list(tweet_data.id)
twi_id = list(twi_arch.tweet_id)
pre_id = list(predict.tweet_id)

for num in pre_id:
    assert num in twi_id
# all twitter id's in prediction table are in twi_arch table
c = list(set(twi_id)^set(pre_id)) # list of id not in predicted table

print(len(c))
# Out:
# 281

# %%
twi_arch[twi_arch.tweet_id.duplicated()] #no duplicated tweets
# Out:
# Empty DataFrame
# Columns: [tweet_id, in_reply_to_status_id, in_reply_to_user_id, timestamp, source, text, retweeted_status_id, retweeted_status_user_id, retweeted_status_timestamp, expanded_urls, rating_numerator, rating_denominator, name, doggo, floofer, pupper, puppo]
# Index: []

# %%
twi_arch.name.str.extractall("(^[a-z]+$)")  # names that are not capitalized are not actualy names
# Out:
#                      0
#      match
# 22   0            such
# 56   0               a
# 118  0           quite
# 169  0           quite
# 193  0           quite
# 335  0             not
# 369  0             one
# 542  0      incredibly
# 649  0               a
# 682  0             mad
# 759  0              an
# 773  0            very
# 801  0               a
# 819  0            very
# 822  0            just
# 852  0              my
# 924  0             one
# 988  0             not
# 992  0             his
# 993  0             one
# 1002 0               a
# 1004 0               a
# 1017 0               a
# 1025 0              an
# 1031 0            very
# 1040 0        actually
# 1049 0               a
# 1063 0            just
# 1071 0         getting
# 1095 0             mad
# ...                ...
# 2191 0               a
# 2198 0               a
# 2204 0              an
# 2211 0               a
# 2212 0             the
# 2218 0               a
# 2222 0               a
# 2235 0               a
# 2249 0               a
# 2255 0               a
# 2264 0               a
# 2273 0               a
# 2287 0               a
# 2304 0               a
# 2311 0               a
# 2314 0               a
# 2326 0           quite
# 2327 0               a
# 2333 0              an
# 2334 0               a
# 2335 0              an
# 2345 0             the
# 2346 0             the
# 2347 0               a
# 2348 0               a
# 2349 0              an
# 2350 0               a
# 2352 0               a
# 2353 0               a
# 2354 0               a
#
# [109 rows x 1 columns]

# %%
twi_arch.loc[649] # actual name is 'Forrest'
# Out:
# tweet_id                                                     792913359805018113
# in_reply_to_status_id                                                       NaN
# in_reply_to_user_id                                                         NaN
# timestamp                                             2016-10-31 02:17:31 +0000
# source                        <a href="http://twitter.com/download/iphone" r...
# text                          Here is a perfect example of someone who has t...
# retweeted_status_id                                                         NaN
# retweeted_status_user_id                                                    NaN
# retweeted_status_timestamp                                                  NaN
# expanded_urls                 https://twitter.com/dog_rates/status/792913359...
# rating_numerator                                                             13
# rating_denominator                                                           10
# name                                                                          a
# doggo                                                                      None
# floofer                                                                    None
# pupper                                                                     None
# puppo                                                                      None
# Name: 649, dtype: object

# %%
twi_arch.expanded_urls[801] # same url multiple times (number of pictures)
twi_arch.expanded_urls[721]
# Out:
# 'https://twitter.com/dog_rates/status/783334639985389568/photo/1,https://twitter.com/dog_rates/status/783334639985389568/photo/1,https://twitter.com/dog_rates/status/783334639985389568/photo/1'

# %%
twi_arch.rating_denominator.value_counts()
# Out:
# 10     2333
# 11        3
# 50        3
# 80        2
# 20        2
# 2         1
# 16        1
# 40        1
# 70        1
# 15        1
# 90        1
# 110       1
# 120       1
# 130       1
# 150       1
# 170       1
# 7         1
# 0         1
# Name: rating_denominator, dtype: int64

# %%
twi_arch.name.value_counts()
# Out:
# None          745
# a              55
# Charlie        12
# Cooper         11
# Lucy           11
# Oliver         11
# Lola           10
# Penny          10
# Tucker         10
# Winston         9
# Bo              9
# the             8
# Sadie           8
# an              7
# Bailey          7
# Toby            7
# Daisy           7
# Buddy           7
# Rusty           6
# Jack            6
# Stanley         6
# Jax             6
# Milo            6
# Koda            6
# Oscar           6
# Scout           6
# Leo             6
# Bella           6
# Dave            6
# Alfie           5
#              ...
# officially      1
# Noosh           1
# Farfle          1
# Pumpkin         1
# Gabby           1
# Alejandro       1
# Jebberson       1
# Juckson         1
# Lucky           1
# Blanket         1
# Jaspers         1
# Covach          1
# Ralphus         1
# Grady           1
# Jennifur        1
# Glacier         1
# Goliath         1
# Mac             1
# Banjo           1
# Rolf            1
# Harry           1
# Tripp           1
# Hanz            1
# Izzy            1
# Emmie           1
# Harrison        1
# Carbon          1
# Kendall         1
# Beckham         1
# Zuzu            1
# Name: name, Length: 957, dtype: int64

# %%
# after having submited my project once, I was informed of a very important issue
twi_arch.text[1689] # source text has a denominator of 9.5
# and for rating_numerator it has a 5, I need to fix this
# Out:
# "I've been told there's a slight possibility he's checking his mirror. We'll bump to 9.5/10. Still a menace"

# %%
predict.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
# tweet_id    2075 non-null int64
# jpg_url     2075 non-null object
# img_num     2075 non-null int64
# p1          2075 non-null object
# p1_conf     2075 non-null float64
# p1_dog      2075 non-null bool
# p2          2075 non-null object
# p2_conf     2075 non-null float64
# p2_dog      2075 non-null bool
# p3          2075 non-null object
# p3_conf     2075 non-null float64
# p3_dog      2075 non-null bool
# dtypes: bool(3), float64(3), int64(2), object(4)
# memory usage: 152.1+ KB

# %%
predict.sample(5)
# Out:
#                 tweet_id                                          jpg_url  \
# 849   695629776980148225  https://pbs.twimg.com/media/Cadfl6zWcAEZqIW.jpg
# 1171  736365877722001409  https://pbs.twimg.com/media/CjgYyuvWkAAHU8g.jpg
# 711   685315239903100929  https://pbs.twimg.com/media/CYK6kf0WMAAzP-0.jpg
# 1938  860524505164394496  https://pbs.twimg.com/media/C_EyeKuXkAAdxY-.jpg
# 647   681679526984871937  https://pbs.twimg.com/media/CXXP5O4WEAA4dgS.jpg
#
#       img_num                    p1   p1_conf  p1_dog          p2   p2_conf  \
# 849         1  Old_English_sheepdog  0.693857    True  otterhound  0.232117
# 1171        3                   cup  0.473555   False  toy_poodle  0.082606
# 711         2                  chow  0.470162    True  Pomeranian  0.159677
# 1938        1    Bedlington_terrier  0.286558    True  toy_poodle  0.235193
# 647         1             birdhouse  0.472351   False       teddy  0.142058
#
#       p2_dog                           p3   p3_conf  p3_dog
# 849     True  West_Highland_white_terrier  0.012867    True
# 1171    True                     consomme  0.048298   False
# 711     True                   Eskimo_dog  0.105074    True
# 1938    True             Lakeland_terrier  0.087951    True
# 647    False                          pot  0.032906   False

# %%
predict.p1_dog.value_counts()
# Out:
# True     1532
# False     543
# Name: p1_dog, dtype: int64

# %%
tweet_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2345 entries, 0 to 2344
# Data columns (total 3 columns):
# id                2345 non-null int64
# retweet_count     2345 non-null int64
# favorite_count    2345 non-null int64
# dtypes: int64(3)
# memory usage: 55.0 KB

# %% [markdown]
# #### Quality (8 issues or more)
# ##### `twi_arch` table
# - retweeted_status_id, retweeted_status_user_id, and retweeted_status_timestamp is information of original tweets.
# - expanded_urls contains urls for number of photos, videos and urls in text of tweet
# - there are 59 missing urls in expanded_urls
# - in_reply_status_id is information of tweets that are replies, but they still score dogs and some have pictures.
# - 'source' is in HTML form, only need source name, no urls.
# - Names are sometimes not real name but other lower-case words
#     - (index: 649) dog with tweet_id: 792913359805018113 is named 'Forrest' not 'a'
# - erronous data types (e.g. tweet_id, reply info, retweet info, timestamps, rating_numerator and denominator, source)
# - text rating and rating_numerator and rating_denominator might not match (after getting rid of retweets and tweets with no pictures)
# - tweet with rating_denominator of 7 is not a tweet of an actual rating
# - two outliers with rating numerator of 420 and 1776
#
# ##### `predict` table
# - for p1, p2, and p3 the breed of the dog has _ instead of white space between words; all should be lower case for consistency
# - tweet_id not integer
#
# ##### `tweet_data` table
# - 'id' variable should be labaled the same as for `twi_arch` table, 'tweet_id'
# - tweet_id not integer
# - 11 tweets not found

# %% [markdown]
# #### Tidiness (2 issues or more)
# - drop uneccessary columns in `twi_arch` (retweets and replies)
# - one variable (dog_stage) in four columns in `twi_arch` table (doggo, floofer, pupper, and puppo)
# - there is no score_ratio value
# - number of images should be in the `predict` table
# - number of likes and retweet count should be in the `twi_arch` table
# - merge the tables of `twi_clean` and `tweet_clean` to get retweet count and favorite count

# %% [markdown]
# # Cleaning Data

# %%
# make copies of the tables
twi_clean = twi_arch.copy()
pre_clean = predict.copy()
tweet_clean = tweet_data.copy()

# %% [markdown]
# #### `twi_arch`: 78 retweets present in this table

# %% [markdown]
# ##### Define
# Delete these tweets. They are not needed since we want original tweets

# %% [markdown]
# ##### Code

# %%
twi_clean = twi_clean[twi_clean.retweeted_status_id.isnull()]

# %% [markdown]
# ##### Test

# %%
# should be empty
twi_clean[twi_clean.retweeted_status_id.notnull()]
# Out:
# Empty DataFrame
# Columns: [tweet_id, in_reply_to_status_id, in_reply_to_user_id, timestamp, source, text, retweeted_status_id, retweeted_status_user_id, retweeted_status_timestamp, expanded_urls, rating_numerator, rating_denominator, name, doggo, floofer, pupper, puppo]
# Index: []

# %%
twi_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2175 entries, 0 to 2355
# Data columns (total 17 columns):
# tweet_id                      2175 non-null int64
# in_reply_to_status_id         78 non-null float64
# in_reply_to_user_id           78 non-null float64
# timestamp                     2175 non-null object
# source                        2175 non-null object
# text                          2175 non-null object
# retweeted_status_id           0 non-null float64
# retweeted_status_user_id      0 non-null float64
# retweeted_status_timestamp    0 non-null object
# expanded_urls                 2117 non-null object
# rating_numerator              2175 non-null int64
# rating_denominator            2175 non-null int64
# name                          2175 non-null object
# doggo                         2175 non-null object
# floofer                       2175 non-null object
# pupper                        2175 non-null object
# puppo                         2175 non-null object
# dtypes: float64(4), int64(3), object(10)
# memory usage: 305.9+ KB

# %% [markdown]
# #### `twi_arch`: expanded_urls contains urls for number of photos, videos and urls in text of tweet

# %% [markdown]
# ##### Define
# Create number of photos in each tweet off expanded_urls

# %% [markdown]
# ##### Code

# %%
# ensures they come from dog_rates

def photo_count(table):
    i = str(table['tweet_id'])
    url = str(table['expanded_urls'])
    s = "https://twitter.com/dog_rates/status/" + i + "/photo/1"
    return url.count(s)

# in case I wanted number of images, but I don't
# def video_count(table):
#     i = str(table['tweet_id'])
#     url = str(table['expanded_urls'])
#     s = "https://twitter.com/dog_rates/status/" + i + "/video/1"
#     return url.count(s)
# twi_clean["num_of_vid"] = twi_clean.apply(video_count, axis=1)

twi_clean["num_of_img"] = twi_clean.apply(photo_count, axis=1)

# %% [markdown]
# ##### Test

# %%
twi_clean.num_of_img.value_counts()
# Out:
# 1    1419
# 2     286
# 0     255
# 4     114
# 3     101
# Name: num_of_img, dtype: int64

# %% [markdown]
# #### `twi_arch`: various tweets have zero images

# %% [markdown]
# ##### Define
# Delete these tweets since we need tweets with images

# %% [markdown]
# ##### Code

# %%
twi_clean = twi_clean[twi_clean.num_of_img != 0]

# %% [markdown]
# ##### Test

# %%
twi_clean.num_of_img.value_counts()
# Out:
# 1    1419
# 2     286
# 4     114
# 3     101
# Name: num_of_img, dtype: int64

# %% [markdown]
# #### `twi_arch`: there are 59 missing urls in expanded_urls; all rows with no expanded_urls do not have picture

# %% [markdown]
# ##### Define
# We only want tweets with pictures, so delete these tweets (rows)

# %% [markdown]
# ##### Code

# %%
twi_clean[twi_clean.expanded_urls.isnull()] # there are no missing expanded_urls anymore
# Out:
# Empty DataFrame
# Columns: [tweet_id, in_reply_to_status_id, in_reply_to_user_id, timestamp, source, text, retweeted_status_id, retweeted_status_user_id, retweeted_status_timestamp, expanded_urls, rating_numerator, rating_denominator, name, doggo, floofer, pupper, puppo, num_of_img]
# Index: []

# %% [markdown]
# ##### Test

# %%
twi_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1920 entries, 0 to 2355
# Data columns (total 18 columns):
# tweet_id                      1920 non-null int64
# in_reply_to_status_id         21 non-null float64
# in_reply_to_user_id           21 non-null float64
# timestamp                     1920 non-null object
# source                        1920 non-null object
# text                          1920 non-null object
# retweeted_status_id           0 non-null float64
# retweeted_status_user_id      0 non-null float64
# retweeted_status_timestamp    0 non-null object
# expanded_urls                 1920 non-null object
# rating_numerator              1920 non-null int64
# rating_denominator            1920 non-null int64
# name                          1920 non-null object
# doggo                         1920 non-null object
# floofer                       1920 non-null object
# pupper                        1920 non-null object
# puppo                         1920 non-null object
# num_of_img                    1920 non-null int64
# dtypes: float64(4), int64(4), object(10)
# memory usage: 285.0+ KB

# %% [markdown]
# #### `twi_arch`: in_reply_status_id is information of tweets that are replies, but they still score dogs and some have pictures

# %% [markdown]
# ##### Define
# Check that all these have a score and a picture.

# %% [markdown]
# ##### Code

# %%
# 1842  https://twitter.com/dog_rates/status/675870721...                11
# 1852  https://twitter.com/dog_rates/status/675707330...                11
# 1866  https://twitter.com/dog_rates/status/675349384...                13
# 1882  https://twitter.com/dog_rates/status/674999807...                13
# 1885  https://twitter.com/dog_rates/status/674793399...                13
# 1892  https://twitter.com/dog_rates/status/674754018...                12
# 2036  https://twitter.com/dog_rates/status/671729906...                13
# 2169  https://twitter.com/dog_rates/status/669353438...                10
#
#       rating_denominator   name  doggo floofer  pupper puppo  num_of_img
# 149                   10   None   None    None    None  None           1
# 184                   10   None   None    None    None  None           1
# 251                   10   None   None    None    None  None           3
# 565                   10   None  doggo    None  pupper  None           1
# 1016                  10   None   None    None    None  None           1
# 1018                  10   None   None    None    None  None           1
# 1330                  10   None   None    None  pupper  None           1
# 1339                  10   None   None    None    None  None           1
# 1356                  10   None   None    None    None  None           1
# 1452                  10   None   None    None    None  None           1
# 1464                  10   None   None    None  pupper  None           1
# 1501                  10   None   None    None    None  None           4
# 1634                 130   None   None    None    None  None           2
# 1842                  10   None   None    None    None  None           1
# 1852                  10   None   None    None    None  None           1
# 1866                  10   None   None    None    None  None           4
# 1882                  10   None   None    None    None  None           1
# 1885                  10   None   None    None    None  None           1
# 1892                  10   None   None    None    None  None           1
# 2036                  10   None   None    None    None  None           1
# 2169                  10  Tessa   None    None    None  None           1

# %% [markdown]
# ##### Test

# %%
# replies are acceptable

# %% [markdown]
# ##### `twi_arch`: 'source' is in HTML form, only need source name, no urls.

# %% [markdown]
# ##### Define
# Use regular expression to extract the source name, not the urls

# %% [markdown]
# ##### Code

# %%
twi_clean['source'] = twi_clean.source.str.extract(">(.*)<", expand=True)

# %% [markdown]
# ##### Test

# %%
twi_clean.source.value_counts()
# Out:
# Twitter for iPhone    1889
# Twitter Web Client      20
# TweetDeck               11
# Name: source, dtype: int64

# %% [markdown]
# #### `twi_arch`: Names are sometimes not real name but other lower-case words
# - (index: 649) dog with tweet_id: 792913359805018113 is named 'Forrest' not 'a'

# %% [markdown]
# ##### Define
# Replace each occurance of a wrong name for Nan, since these tweets most likely did not include a name. There is an occurance in index 649 where the dog's name is 'Forrest'

# %% [markdown]
# ##### Code

# %%
x = twi_clean.name.str.extractall("(^[a-z]+$)")
x.xs(0, level='match')
all_wrong_names = x[0].tolist()
wrong_names = list(set(all_wrong_names)) # get only the unique values
wrong_names
# Out:
# ['an',
#  'incredibly',
#  'actually',
#  'his',
#  'quite',
#  'my',
#  'infuriating',
#  'the',
#  'not',
#  'all',
#  'very',
#  'space',
#  'a',
#  'this',
#  'unacceptable',
#  'getting',
#  'just',
#  'light',
#  'one',
#  'by']

# %%
def a_to_none(s):
    if s in wrong_names:
        return nan
    else:
        return s
    
twi_clean['name'] = twi_clean.name.map(a_to_none)
twi_clean.loc[649, 'name'] = 'Forrest'  # 'Forrest' with double 'r'

# %% [markdown]
# ##### Test

# %%
twi_clean.name.str.extractall("(^[a-z]+$)")
# Out:
# Empty DataFrame
# Columns: [0]
# Index: []

# %%
twi_clean[twi_clean.name == 'Forrest']
# Out:
#                tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 649  792913359805018113                    NaN                  NaN
#
#                      timestamp              source  \
# 649  2016-10-31 02:17:31 +0000  Twitter for iPhone
#
#                                                   text  retweeted_status_id  \
# 649  Here is a perfect example of someone who has t...                  NaN
#
#      retweeted_status_user_id retweeted_status_timestamp  \
# 649                       NaN                        NaN
#
#                                          expanded_urls  rating_numerator  \
# 649  https://twitter.com/dog_rates/status/792913359...                13
#
#      rating_denominator     name doggo floofer pupper puppo  num_of_img
# 649                  10  Forrest  None    None   None  None           4

# %% [markdown]
# #### `twi_arch`: erronous data types (e.g. tweet_id, reply info, retweet info, timestamps, rating_numerator and denominator, source)

# %% [markdown]
# ##### Define
# Change variables to appropitate data types

# %% [markdown]
# ##### Code

# %%
# To category
twi_clean.source = twi_clean.source.astype('category')

# To datetime
twi_clean.timestamp = pd.to_datetime(twi_clean.timestamp)
twi_clean.retweeted_status_timestamp = pd.to_datetime(twi_clean.retweeted_status_timestamp)  # even though I am droping this column

# To string
twi_clean.tweet_id = twi_clean.tweet_id.astype(str)
twi_clean.in_reply_to_status_id = twi_clean.in_reply_to_status_id.astype(str) # even though I am droping this column
twi_clean.in_reply_to_user_id = twi_clean.in_reply_to_user_id.astype(str) # even though I am droping this column
twi_clean.retweeted_status_id = twi_clean.retweeted_status_id.astype(str) # even though I am droping this column
twi_clean.retweeted_status_user_id = twi_clean.retweeted_status_user_id.astype(str)  # even though I am droping this column

# To float since I am going to get correct numerators which can be floats
twi_clean.rating_numerator = twi_clean.rating_numerator.astype(float)
twi_clean.rating_denominator = twi_clean.rating_denominator.astype(float)

# %% [markdown]
# ##### Test

# %%
twi_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1920 entries, 0 to 2355
# Data columns (total 18 columns):
# tweet_id                      1920 non-null object
# in_reply_to_status_id         1920 non-null object
# in_reply_to_user_id           1920 non-null object
# timestamp                     1920 non-null datetime64[ns]
# source                        1920 non-null category
# text                          1920 non-null object
# retweeted_status_id           1920 non-null object
# retweeted_status_user_id      1920 non-null object
# retweeted_status_timestamp    0 non-null datetime64[ns]
# expanded_urls                 1920 non-null object
# rating_numerator              1920 non-null float64
# rating_denominator            1920 non-null float64
# name                          1829 non-null object
# doggo                         1920 non-null object
# floofer                       1920 non-null object
# pupper                        1920 non-null object
# puppo                         1920 non-null object
# num_of_img                    1920 non-null int64
# dtypes: category(1), datetime64[ns](2), float64(2), int64(1), object(12)
# memory usage: 352.0+ KB

# %% [markdown]
# #### `twi_arch`: source text rating and rating_numerator and rating_denominator might not match

# %% [markdown]
# ##### Define
# Use regex to get the correct numerator and denominators from text

# %% [markdown]
# ##### Code

# %%
c = twi_clean.text.str.extractall("([0-9]+[.][0-9]+\/\d+)")
d = c.xs(0, level='match')
d.loc[:,'rating_numerator'], d.loc[:,'rating_denominator'] = d[0].str.split('/', 1).str
d.rating_numerator = d.rating_numerator.astype(float)
d.rating_denominator = d.rating_denominator.astype(float)
d = d.drop(0, axis=1)
d
# Out:
#       rating_numerator  rating_denominator
# 45               13.50                10.0
# 695               9.75                10.0
# 763              11.27                10.0
# 1712             11.26                10.0

# %% [markdown]
# Need to change the above ratings

# %%
twi_clean.update(d)
index_rating_decimal = [45, 695, 763, 1712]  # updated ratings with decimal places

# %% [markdown]
# These tweets have at least two ratings or similar to a rating.
#
# index: first,second or average (XXX indicates that I won't need to change them)
# - 766 second
# - 1007 average
# - 1068 second
# - 1165 second
# - 1202 second
# - 1222 average
# - 1359 first XXX
# - 1465 first XXX
# - 1508 average
# - 1525 first XXX
# - 1538 average
# - 1662 second
# - 1795 average
# - 1832 first XXX
# - 1897 first XXX
# - 1901 second
# - 1970 first XXX
# - 2010 first XXX
# - 2064 first XXX
# - 2113 average
# - 2177 average
# - 2216 first XXX
# - 2263 average
# - 2272 first XXX
# - 2306 average but it's both 10/10 XXX
# - 2335 second

# %%
a = twi_clean.text.str.extractall("(\d+\/\d+)")
f = a.xs(1, level='match')
f.loc[:,'rating_numerator'], f.loc[:,'rating_denominator'] = f[0].str.split('/', 1).str
f.rating_numerator = f.rating_numerator.astype(float)
f.rating_denominator = f.rating_denominator.astype(float)
f = f.drop(0, axis=1)

g = a.xs(0, level='match')
g.loc[:,'rating_numerator'], g.loc[:,'rating_denominator'] = g[0].str.split('/', 1).str
g.rating_numerator = g.rating_numerator.astype(float)
g.rating_denominator = g.rating_denominator.astype(float)
g = g.drop(0, axis=1)
# Out:
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexing.py:337: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexing.py:517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /opt/conda/lib/python3.6/site-packages/pandas/core/generic.py:3110: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
to_drop = [1359, 1465, 1525, 1832, 1897, 1970, 2010, 2064, 2216, 2272, 2306] # these will stay as they are in twi_clean
f = f.drop(to_drop)

# %%
average_list = [1007, 1222, 1508, 1538, 1795, 2113, 2177, 2263]
for index in average_list:  # average values since there were two dogs and two scores
    n1 = f.loc[index, 'rating_numerator']
    n2 = g.loc[index, 'rating_numerator']
    f.loc[index, 'rating_numerator'] = (n1 + n2) / 2

# %%
twi_clean.update(f)
# updated ratings that had two ratings (average or just the second one was correct)

# %% [markdown]
# ##### Test

# %%
twi_clean.loc[average_list]
# Out:
#                 tweet_id in_reply_to_status_id in_reply_to_user_id  \
# 1007  747600769478692864                   nan                 nan
# 1222  714258258790387713                   nan                 nan
# 1508  691483041324204033                   nan                 nan
# 1538  689835978131935233                   nan                 nan
# 1795  677314812125323265                   nan                 nan
# 2113  670434127938719744                   nan                 nan
# 2177  669037058363662336                   nan                 nan
# 2263  667544320556335104                   nan                 nan
#
#                timestamp              source  \
# 1007 2016-06-28 01:21:27  Twitter for iPhone
# 1222 2016-03-28 01:10:13  Twitter for iPhone
# 1508 2016-01-25 04:49:38  Twitter for iPhone
# 1538 2016-01-20 15:44:48  Twitter for iPhone
# 1795 2015-12-17 02:30:09  Twitter for iPhone
# 2113 2015-11-28 02:48:46  Twitter for iPhone
# 2177 2015-11-24 06:17:19  Twitter for iPhone
# 2263 2015-11-20 03:25:43  Twitter Web Client
#
#                                                    text retweeted_status_id  \
# 1007  This is Bookstore and Seaweed. Bookstore is ti...                 nan
# 1222  Meet Travis and Flurp. Travis is pretty chill ...                 nan
# 1508  When bae says they can't go out but you see th...                 nan
# 1538  Meet Fynn &amp; Taco. Fynn is an all-powerful ...                 nan
# 1795  Meet Tassy &amp; Bee. Tassy is pretty chill, b...                 nan
# 2113  Meet Hank and Sully. Hank is very proud of the...                 nan
# 2177  Here we have Pancho and Peaches. Pancho is a C...                 nan
# 2263  This is Kial. Kial is either wearing a cape, w...                 nan
#
#      retweeted_status_user_id retweeted_status_timestamp  \
# 1007                      nan                        NaT
# 1222                      nan                        NaT
# 1508                      nan                        NaT
# 1538                      nan                        NaT
# 1795                      nan                        NaT
# 2113                      nan                        NaT
# 2177                      nan                        NaT
# 2263                      nan                        NaT
#
#                                           expanded_urls  rating_numerator  \
# 1007  https://twitter.com/dog_rates/status/747600769...               8.5
# 1222  https://twitter.com/dog_rates/status/714258258...               9.0
# 1508  https://twitter.com/dog_rates/status/691483041...               7.5
# 1538  https://twitter.com/dog_rates/status/689835978...              10.5
# 1795  https://twitter.com/dog_rates/status/677314812...              10.5
# 2113  https://twitter.com/dog_rates/status/670434127...               9.5
# 2177  https://twitter.com/dog_rates/status/669037058...               8.5
# 2263  https://twitter.com/dog_rates/status/667544320...               7.0
#
#       rating_denominator       name doggo floofer pupper puppo  num_of_img
# 1007                10.0  Bookstore  None    None   None  None           2
# 1222                10.0     Travis  None    None   None  None           1
# 1508                10.0       None  None    None   None  None           4
# 1538                10.0       Fynn  None    None   None  None           1
# 1795                10.0      Tassy  None    None   None  None           2
# 2113                10.0       Hank  None    None   None  None           1
# 2177                10.0       None  None    None   None  None           1
# 2263                10.0       Kial  None    None   None  None           1

# %%
twi_clean.loc[index_rating_decimal]
# Out:
#                 tweet_id in_reply_to_status_id in_reply_to_user_id  \
# 45    883482846933004288                   nan                 nan
# 695   786709082849828864                   nan                 nan
# 763   778027034220126208                   nan                 nan
# 1712  680494726643068929                   nan                 nan
#
#                timestamp              source  \
# 45   2017-07-08 00:28:19  Twitter for iPhone
# 695  2016-10-13 23:23:56  Twitter for iPhone
# 763  2016-09-20 00:24:34  Twitter for iPhone
# 1712 2015-12-25 21:06:00  Twitter for iPhone
#
#                                                    text retweeted_status_id  \
# 45    This is Bella. She hopes her smile made you sm...                 nan
# 695   This is Logan, the Chow who lived. He solemnly...                 nan
# 763   This is Sophie. She's a Jubilant Bush Pupper. ...                 nan
# 1712  Here we have uncovered an entire battalion of ...                 nan
#
#      retweeted_status_user_id retweeted_status_timestamp  \
# 45                        nan                        NaT
# 695                       nan                        NaT
# 763                       nan                        NaT
# 1712                      nan                        NaT
#
#                                           expanded_urls  rating_numerator  \
# 45    https://twitter.com/dog_rates/status/883482846...             13.50
# 695   https://twitter.com/dog_rates/status/786709082...              9.75
# 763   https://twitter.com/dog_rates/status/778027034...             11.27
# 1712  https://twitter.com/dog_rates/status/680494726...             11.26
#
#       rating_denominator    name doggo floofer  pupper puppo  num_of_img
# 45                  10.0   Bella  None    None    None  None           2
# 695                 10.0   Logan  None    None    None  None           1
# 763                 10.0  Sophie  None    None  pupper  None           1
# 1712                10.0    None  None    None    None  None           1

# %% [markdown]
# #### `twi_arch`: tweet with rating_denominator of 7 is not a tweet of an actual rating

# %% [markdown]
# ##### Define
# Delete this tweet from the data

# %% [markdown]
# ##### Code

# %%
not_rating = twi_clean.index[twi_clean.rating_denominator == 7.0].tolist() # not a rating, need to delete tweet
twi_clean = twi_clean.drop(not_rating)  # it's a dog that's sick and needs help raising money (I think...)

# %% [markdown]
# ##### Test

# %%
twi_clean[twi_clean.rating_denominator == 7.0]
# Out:
# Empty DataFrame
# Columns: [tweet_id, in_reply_to_status_id, in_reply_to_user_id, timestamp, source, text, retweeted_status_id, retweeted_status_user_id, retweeted_status_timestamp, expanded_urls, rating_numerator, rating_denominator, name, doggo, floofer, pupper, puppo, num_of_img]
# Index: []

# %% [markdown]
# #### `twi_arch`: two outliers with rating numerator of 420 and 1776

# %% [markdown]
# ##### Define
# Remove these two outliers

# %% [markdown]
# ##### Code

# %%
not_rating = twi_clean.index[twi_clean.rating_numerator == 420.0].tolist()
twi_clean = twi_clean.drop(not_rating)  # Snoop Dog...

not_rating = twi_clean.index[twi_clean.rating_numerator == 1776.0].tolist()  
twi_clean = twi_clean.drop(not_rating)  # Dog celebrating July 4th

# %% [markdown]
# ##### Test

# %%
twi_clean[twi_clean.rating_numerator == 420.0]
# Out:
# Empty DataFrame
# Columns: [tweet_id, in_reply_to_status_id, in_reply_to_user_id, timestamp, source, text, retweeted_status_id, retweeted_status_user_id, retweeted_status_timestamp, expanded_urls, rating_numerator, rating_denominator, name, doggo, floofer, pupper, puppo, num_of_img]
# Index: []

# %%
twi_clean[twi_clean.rating_numerator == 1776.0]
# Out:
# Empty DataFrame
# Columns: [tweet_id, in_reply_to_status_id, in_reply_to_user_id, timestamp, source, text, retweeted_status_id, retweeted_status_user_id, retweeted_status_timestamp, expanded_urls, rating_numerator, rating_denominator, name, doggo, floofer, pupper, puppo, num_of_img]
# Index: []

# %% [markdown]
# #### `predict`: for p1, p2, and p3 the breed of the dog has _ instead of white space between words; all should be lower case for consistency

# %% [markdown]
# ##### Define
# raplce _ for a white space and lower case all leters

# %% [markdown]
# ##### Code

# %%
pre_clean['p1'] = pre_clean.p1.str.replace('_', ' ').str.lower()
pre_clean['p2'] = pre_clean.p2.str.replace('_', ' ').str.lower()
pre_clean['p3'] = pre_clean.p3.str.replace('_', ' ').str.lower()

# %% [markdown]
# ##### Test

# %%
pre_clean.sample(10)
# Out:
#                 tweet_id                                          jpg_url  \
# 68    667182792070062081  https://pbs.twimg.com/media/CUJPNjOWsAAZRqP.jpg
# 1669  813066809284972545  https://pbs.twimg.com/media/C0iX8OOVEAEIpMC.jpg
# 1254  748324050481647620  https://pbs.twimg.com/media/CmKUwImXIAA58f5.jpg
# 1955  864279568663928832  https://pbs.twimg.com/media/C_6JrWZVwAAHhCD.jpg
# 1608  800751577355128832  https://pbs.twimg.com/media/CxzXOyBW8AEu_Oi.jpg
# 1419  771500966810099713  https://pbs.twimg.com/media/CrTsCPHWYAANdzC.jpg
# 1423  772117678702071809  https://pbs.twimg.com/media/Crcc7pqXEAAM5O2.jpg
# 1165  735274964362878976  https://pbs.twimg.com/media/CjQ4radW0AENP-m.jpg
# 226   670361874861563904  https://pbs.twimg.com/media/CU2akCQWsAIbaOV.jpg
# 1783  829011960981237760  https://pbs.twimg.com/media/C4E99ygWcAAQpPs.jpg
#
#       img_num                  p1   p1_conf  p1_dog                  p2  \
# 68          1    golden retriever  0.949892    True        irish setter
# 1669        1         toy terrier  0.776400    True            pembroke
# 1254        1   shetland sheepdog  0.880499    True              collie
# 1955        1        bull mastiff  0.668613    True      french bulldog
# 1608        2      cocker spaniel  0.771984    True    miniature poodle
# 1419        1  labrador retriever  0.833952    True    golden retriever
# 1423        1  labrador retriever  0.217821    True              beagle
# 1165        1        studio couch  0.944692   False         four-poster
# 226         1            platypus  0.974075   False  spotted salamander
# 1783        2               boxer  0.312221    True           dalmatian
#
#        p2_conf  p2_dog                         p3   p3_conf  p3_dog
# 68    0.010564    True   chesapeake bay retriever  0.005821    True
# 1669  0.115034    True                    basenji  0.048873    True
# 1254  0.107901    True                   pembroke  0.003607    True
# 1955  0.180562    True  staffordshire bullterrier  0.052237    True
# 1608  0.076653    True                 toy poodle  0.039618    True
# 1419  0.103223    True                soccer ball  0.012094   False
# 1423  0.157677    True           golden retriever  0.127726    True
# 1165  0.007942   False                      quilt  0.006302   False
# 226   0.011068   False                      bison  0.003897   False
# 1783  0.244040    True                      conch  0.130273   False

# %% [markdown]
# #### `predict`: tweet_id is not integer type

# %% [markdown]
# ##### Define
# Change tweet_id's data type to str

# %% [markdown]
# ##### Code

# %%
pre_clean.tweet_id = pre_clean.tweet_id.astype(str)

# %% [markdown]
# ##### Test

# %%
pre_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
# tweet_id    2075 non-null object
# jpg_url     2075 non-null object
# img_num     2075 non-null int64
# p1          2075 non-null object
# p1_conf     2075 non-null float64
# p1_dog      2075 non-null bool
# p2          2075 non-null object
# p2_conf     2075 non-null float64
# p2_dog      2075 non-null bool
# p3          2075 non-null object
# p3_conf     2075 non-null float64
# p3_dog      2075 non-null bool
# dtypes: bool(3), float64(3), int64(1), object(5)
# memory usage: 152.1+ KB

# %% [markdown]
# #### `tweet_data`: 'id' variable should be labaled the same as for `twi_arch` table, 'tweet_id'

# %% [markdown]
# ##### Define
# Change 'id' to 'tweet_id'

# %% [markdown]
# ##### Code

# %%
tweet_clean.rename(columns={'id':'tweet_id'}, inplace=True)

# %% [markdown]
# ##### Test

# %%
tweet_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2345 entries, 0 to 2344
# Data columns (total 3 columns):
# tweet_id          2345 non-null int64
# retweet_count     2345 non-null int64
# favorite_count    2345 non-null int64
# dtypes: int64(3)
# memory usage: 73.3 KB

# %% [markdown]
# #### `tweet_data`: tweet_id is not integer type

# %% [markdown]
# ##### Define
# Change tweet_id to str type

# %% [markdown]
# ##### Code

# %%
tweet_clean.tweet_id = tweet_clean.tweet_id.astype(str)

# %% [markdown]
# ##### Test

# %%
tweet_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2345 entries, 0 to 2344
# Data columns (total 3 columns):
# tweet_id          2345 non-null object
# retweet_count     2345 non-null int64
# favorite_count    2345 non-null int64
# dtypes: int64(2), object(1)
# memory usage: 73.3+ KB

# %% [markdown]
# # Tidiness

# %% [markdown]
# #### Drop the values for retweets and for replies.

# %% [markdown]
# ##### Define
# Drop theses columns by simply using the drop function in pandas

# %% [markdown]
# ##### Code

# %%
not_needed = ['in_reply_to_status_id', 'in_reply_to_user_id', 'retweeted_status_id', 'retweeted_status_user_id', 'retweeted_status_timestamp']
twi_clean = twi_clean.drop(not_needed, axis=1)

# %% [markdown]
# ##### Test

# %%
list(twi_clean)
# Out:
# ['tweet_id',
#  'timestamp',
#  'source',
#  'text',
#  'expanded_urls',
#  'rating_numerator',
#  'rating_denominator',
#  'name',
#  'doggo',
#  'floofer',
#  'pupper',
#  'puppo',
#  'num_of_img']

# %% [markdown]
# #### One variable (dog_stage) in four columns in `twi_arch` table (doggo, floofer, pupper, and puppo)

# %% [markdown]
# ##### Define
# Combine these four columns to make one under the value "dog_stage"

# %% [markdown]
# ##### Code

# %%
twi_clean['dog_stage'] = twi_clean[twi_clean.columns[8:12]].apply(lambda x: ''.join(x), axis=1).str.replace('None','')
twi_clean['dog_stage'] = twi_clean.dog_stage.map(lambda x: nan if x == '' else x)

twi_clean = twi_clean.drop(['doggo', 'floofer', 'pupper', 'puppo'], axis=1)

# %%
## There is a couple that is two stages of dog
twi_clean['dog_stage'] = twi_clean.dog_stage.str.replace('doggopupper', 'doggo-pupper')
twi_clean['dog_stage'] = twi_clean.dog_stage.str.replace('doggopuppo', 'doggo-puppo')
twi_clean['dog_stage'] = twi_clean.dog_stage.str.replace('doggofloofer', 'doggo-floofer')

# %% [markdown]
# ##### Test

# %%
twi_clean.dog_stage.value_counts()
# Out:
# pupper           194
# doggo             55
# puppo             22
# doggo-pupper       8
# floofer            6
# doggo-floofer      1
# doggo-puppo        1
# Name: dog_stage, dtype: int64

# %% [markdown]
# #### There is no score_ratio value

# %% [markdown]
# ##### Define
# Obtain the ratio from the rating numerator and denominator

# %% [markdown]
# ##### Code

# %%
twi_clean['rating_ratio'] = twi_clean['rating_numerator'] / twi_clean['rating_denominator']

# %% [markdown]
# ##### Test

# %%
twi_clean.sample(5)
# Out:
#                 tweet_id           timestamp              source  \
# 758   778408200802557953 2016-09-21 01:39:11  Twitter for iPhone
# 199   854120357044912130 2017-04-17 23:52:16  Twitter for iPhone
# 2253  667793409583771648 2015-11-20 19:55:30  Twitter for iPhone
# 1903  674638615994089473 2015-12-09 17:15:54  Twitter for iPhone
# 1385  700747788515020802 2016-02-19 18:24:26  Twitter for iPhone
#
#                                                    text  \
# 758   RIP Loki. Thank you for the good times. You wi...
# 199   Sometimes you guys remind me just how impactfu...
# 2253  Dogs only please. Small cows and other non can...
# 1903  This pupper is fed up with being tickled. 12/1...
# 1385  We only rate dogs. Pls stop sending in non-can...
#
#                                           expanded_urls  rating_numerator  \
# 758   https://twitter.com/dog_rates/status/778408200...              14.0
# 199   https://twitter.com/dog_rates/status/854120357...              14.0
# 2253  https://twitter.com/dog_rates/status/667793409...               8.0
# 1903  https://twitter.com/dog_rates/status/674638615...              12.0
# 1385  https://twitter.com/dog_rates/status/700747788...              11.0
#
#       rating_denominator  name  num_of_img dog_stage  rating_ratio
# 758                 10.0  None           4       NaN           1.4
# 199                 10.0  None           4    pupper           1.4
# 2253                10.0  None           1       NaN           0.8
# 1903                10.0  None           1    pupper           1.2
# 1385                10.0   NaN           1       NaN           1.1

# %% [markdown]
# #### number of images should be in the `predict` table, also delete tweets in `predict` not present in `twi_arch`

# %% [markdown]
# ##### Define
# Place the number of pictures in the `predict` table and drop it from the `twi_arch` table. Delete tweets not in `twi_arch`

# %% [markdown]
# ##### Code

# %%
pre_clean = pd.merge(pre_clean, twi_clean[['tweet_id','num_of_img']], on='tweet_id', how='inner')
twi_clean = twi_clean.drop('num_of_img', axis=1)

# %%
# conver num_of_img back to int
pre_clean['num_of_img'] = pre_clean.num_of_img.astype(int)

# %%
pre_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1917 entries, 0 to 1916
# Data columns (total 13 columns):
# tweet_id      1917 non-null object
# jpg_url       1917 non-null object
# img_num       1917 non-null int64
# p1            1917 non-null object
# p1_conf       1917 non-null float64
# p1_dog        1917 non-null bool
# p2            1917 non-null object
# p2_conf       1917 non-null float64
# p2_dog        1917 non-null bool
# p3            1917 non-null object
# p3_conf       1917 non-null float64
# p3_dog        1917 non-null bool
# num_of_img    1917 non-null int64
# dtypes: bool(3), float64(3), int64(2), object(5)
# memory usage: 170.4+ KB

# %% [markdown]
# #### number of likes and retweet count should be in the `twi_arch` table

# %% [markdown]
# ##### Define
# merge the tables of `twi_clean` and `tweet_clean` to get retweet count and favorite count

# %% [markdown]
# ##### Code

# %%
twi_clean = pd.merge(twi_clean, tweet_clean, on='tweet_id', how='left')

# %% [markdown]
# ##### Test

# %%
twi_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1917 entries, 0 to 1916
# Data columns (total 12 columns):
# tweet_id              1917 non-null object
# timestamp             1917 non-null datetime64[ns]
# source                1917 non-null category
# text                  1917 non-null object
# expanded_urls         1917 non-null object
# rating_numerator      1917 non-null float64
# rating_denominator    1917 non-null float64
# name                  1826 non-null object
# dog_stage             287 non-null object
# rating_ratio          1917 non-null float64
# retweet_count         1917 non-null int64
# favorite_count        1917 non-null int64
# dtypes: category(1), datetime64[ns](1), float64(3), int64(2), object(5)
# memory usage: 181.7+ KB

# %% [markdown]
# #### Combine `predictions` tale and `twi_arch` table

# %% [markdown]
# ##### Define
# merge the tables of `twi_clean` and `tweet_clean` to get retweet count and favorite count

# %% [markdown]
# ##### Code

# %%
twi_clean = pd.merge(twi_clean, pre_clean, on='tweet_id', how='left')

# %% [markdown]
# ##### Test

# %%
list(twi_clean)
# Out:
# ['tweet_id',
#  'timestamp',
#  'source',
#  'text',
#  'expanded_urls',
#  'rating_numerator',
#  'rating_denominator',
#  'name',
#  'dog_stage',
#  'rating_ratio',
#  'retweet_count',
#  'favorite_count',
#  'jpg_url',
#  'img_num',
#  'p1',
#  'p1_conf',
#  'p1_dog',
#  'p2',
#  'p2_conf',
#  'p2_dog',
#  'p3',
#  'p3_conf',
#  'p3_dog',
#  'num_of_img']

# %% [markdown]
# # Save our Master Tables

# %%
# re-arange columns to look better
twi_master = twi_clean[['tweet_id', 'timestamp', 'source', 'expanded_urls', 'text', 'name', 'dog_stage',
                        'rating_numerator', 'rating_denominator', 'rating_ratio', 'retweet_count',
                        'favorite_count', 'num_of_img', 'img_num', 'jpg_url', 'p1', 'p1_conf', 'p1_dog',
                        'p2', 'p2_conf', 'p2_dog', 'p3', 'p3_conf', 'p3_dog']]

# %%
twi_master.to_csv('twitter_archive_master.csv', index=False)

# %% [markdown]
# # Analyze

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np
from scipy import stats

# %%
twi_master.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1917 entries, 0 to 1916
# Data columns (total 24 columns):
# tweet_id              1917 non-null object
# timestamp             1917 non-null datetime64[ns]
# source                1917 non-null category
# expanded_urls         1917 non-null object
# text                  1917 non-null object
# name                  1826 non-null object
# dog_stage             287 non-null object
# rating_numerator      1917 non-null float64
# rating_denominator    1917 non-null float64
# rating_ratio          1917 non-null float64
# retweet_count         1917 non-null int64
# favorite_count        1917 non-null int64
# num_of_img            1917 non-null int64
# img_num               1917 non-null int64
# jpg_url               1917 non-null object
# p1                    1917 non-null object
# p1_conf               1917 non-null float64
# p1_dog                1917 non-null bool
# p2                    1917 non-null object
# p2_conf               1917 non-null float64
# p2_dog                1917 non-null bool
# p3                    1917 non-null object
# p3_conf               1917 non-null float64
# p3_dog                1917 non-null bool
# dtypes: bool(3), category(1), datetime64[ns](1), float64(6), int64(4), object(9)
# memory usage: 322.1+ KB

# %%
twi_master.describe()
# Out:
#        rating_numerator  rating_denominator  rating_ratio  retweet_count  \
# count       1917.000000         1917.000000   1917.000000    1917.000000
# mean          11.020751           10.459051      1.050432    2487.403234
# std            7.992286            6.683887      0.217399    3654.287723
# min            0.000000           10.000000      0.000000      13.000000
# 25%           10.000000           10.000000      1.000000     600.000000
# 50%           11.000000           10.000000      1.100000    1297.000000
# 75%           12.000000           10.000000      1.200000    3023.000000
# max          204.000000          170.000000      1.400000   49506.000000
#
#        favorite_count   num_of_img      img_num      p1_conf       p2_conf  \
# count     1917.000000  1917.000000  1917.000000  1917.000000  1.917000e+03
# mean      8440.236828     1.432968     1.211268     0.600136  1.336808e-01
# std      11423.053391     0.841461     0.570425     0.271271  1.007730e-01
# min         80.000000     1.000000     1.000000     0.044333  1.011300e-08
# 25%       1855.000000     1.000000     1.000000     0.369063  5.274420e-02
# 50%       3938.000000     1.000000     1.000000     0.599076  1.174020e-01
# 75%      10879.000000     2.000000     1.000000     0.853684  1.942070e-01
# max     144058.000000     4.000000     4.000000     1.000000  4.880140e-01
#
#             p3_conf
# count  1.917000e+03
# mean   5.960296e-02
# std    5.093652e-02
# min    1.740170e-10
# 25%    1.543210e-02
# 50%    4.914760e-02
# 75%    9.064410e-02
# max    2.734190e-01

# %%
twi_master.rating_ratio.value_counts()
# Out:
# 1.200    432
# 1.000    410
# 1.100    392
# 1.300    236
# 0.900    151
# 0.800     94
# 0.700     52
# 0.600     32
# 0.500     30
# 1.400     30
# 0.300     19
# 0.400     14
# 0.200      9
# 0.100      4
# 1.050      2
# 0.850      2
# 0.000      2
# 1.127      1
# 1.350      1
# 1.126      1
# 0.950      1
# 0.975      1
# 0.750      1
# Name: rating_ratio, dtype: int64

# %% [markdown]
# An insight comes from the rating for each tweet. Since a couple of tweets do not have a rating denominator of 10, either because there is more than one dog in the picture and 'WeRateDogs' added all the ratings together, I created a new variable to obtain the ratio between the rating numerator and the rating denominator. The rating ratio has a mean value of 1.05 and a median on 1.1, which means that on average more dogs obtain a higher rating numerator than denominator. This is common for the Twitter account 'WeRateDogs', since they usually give scores such as 11/10 or 13/10.

# %%
twi_master.p1_dog.value_counts()
# Out:
# True     1428
# False     489
# Name: p1_dog, dtype: int64

# %%
1428 / (1428+489)
# Out:
# 0.7449139280125195

# %% [markdown]
# The confidence percent for the number one prediction from a picture has a flat distribution, with a mean of 60% and a median of 60%. The histogram below shows the confidence percent for all three predictions. As we can see, the histogram for the number one prediction is pretty flat until we reach confidence levels of about 95% and more. From this histogram it is clear that the number one prediction is considerably more accurate than the other two predictions. Noting that from the number one prediction only 74% is actually a dog breed, I can think of two possibilities. Either the dog in the picture was wearing a costume or the dog simply looked like another thing.

# %%
n, bins, patches = plt.hist(twi_master.p1_conf, 30, alpha=0.75, label='# 1')
n, bins, patches = plt.hist(twi_master.p2_conf, 20, alpha=0.75, label='# 2')
n, bins, patches = plt.hist(twi_master.p3_conf, 14, alpha=0.75, label='# 3')
plt.legend(title='Prediction')
plt.xlabel("Percent (%)")
plt.ylabel("Count")

# plt.savefig("p_conf_hist.pdf")
# Out:
# Text(0,0.5,'Count')

# %%
count = list(twi_master.p1_dog.value_counts())
x_pos = np.arange(2)
x_labels = ['Dog Breed', 'Other']

plt.bar(x_pos, count, align='center', alpha=0.5)
plt.xticks(x_pos, x_labels)
plt.title("Number 1 Image Prediction")
plt.ylabel("Count")

# plt.savefig("p1_dog_bar.pdf")
# Out:
# Text(0,0.5,'Count')

# %%
plt.plot(twi_master.rating_ratio, twi_master.favorite_count, 'k.', alpha=1/20)
plt.ylabel('Favorite Count')
plt.xlabel('Rating Ratio')
# Out:
# Text(0.5,0,'Rating Ratio')

# %%
plt.plot(twi_master.favorite_count, twi_master.retweet_count, 'b.', alpha=1/20)
plt.xlim([-2000, 60000])
plt.ylim([-1000, 17500])
plt.xlabel('Favorite Count')
plt.ylabel('Retweet Count')

slope, intercept, r_value, p_value, std_err = stats.linregress(twi_master.favorite_count, twi_master.retweet_count)
print("The correlation coefficient between favorite and retweet count is {:.2f}".format(r_value))

# plt.savefig("fav_ret.pdf")
# Out:
# The correlation coefficient between favorite and retweet count is 0.93

# %% [markdown]
# Another insight I found while analyzing the data, was that the favorite count was very much correlated to the retweet count. Looking at the figure above, we can see that as the favorite count increases, the retweet count increases as well. It is also good to note that tweets, on average get more favorites than are being retweeted. These two variables have a positive correlation coefficient of 0.94.
